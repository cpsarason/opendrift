# %%
from datetime import datetime, timedelta
from opendrift.models.oceandrift import OceanDrift
from opendrift.readers import reader_ROMS_native
import xarray as xr
import numpy as np

#from opendrift.readers.reader_ROMS_native import Reader
        # ds = xr.open_dataset(filename, decode_times=False)
        # r = Reader(ds)

o2=[]
# Basic ocean drift module: current + 2% of wind
o2 = OceanDrift(loglevel=20)

#o2.set_config('general:coastline_action', 'none')
#o2.set_config('general:use_auto_landmask', False)


netCDFs = '/import/VERTMIX/DABOB_JGP/HC_100m_30layers/Experiments/HC_100m_2024.04.09/netcdfOutput/hc_his_*.nc'
grid = '/import/VERTMIX/DABOB_JGP/HC_100m_30layers/Experiments/HC_100m_2024.04.09/HC_100mME_wetDry.nc'
#grid = './test_grid_lonshift.nc'

hc_ds = xr.open_mfdataset(netCDFs)
hc_grid_ds = xr.open_dataset(grid)

hc_native = reader_ROMS_native.Reader(f'{netCDFs}',gridfile=grid)

o2.add_reader(hc_native,)
# Out:
# 13:49:38 INFO    opendrift.models.basemodel:528: OpenDriftSimulation initialised (version 1.11.1 / v1.11.1-26-gc27e2f6-dirty)
# 13:49:39 INFO    opendrift.readers.reader_ROMS_native:148: Opening dataset: /import/VERTMIX/DABOB_JGP/HC_100m_30layers/Experiments/HC_100m_2024.04.09/netcdfOutput/hc_his_*.nc
# 13:49:39 INFO    opendrift.readers.reader_ROMS_native:150: Opening files with MFDataset
# 13:49:39 INFO    opendrift.readers.reader_ROMS_native:246: Read GLS parameters from file.
# 13:49:39 WARNING opendrift.readers.basereader.structured:50: No proj string or projection could be derived, using 'fakeproj'. This assumes that the variables are structured and gridded approximately equidistantly on the surface (i.e. in meters). This must be guaranteed by the user. You can get rid of this warning by supplying a valid projection to the reader.
# 13:49:39 INFO    opendrift.readers.basereader.structured:90: Making interpolator for lon,lat to x,y conversion...

# %% [markdown]
# # Seed the drift model with 100 particles
#
# Particles will be distributed in a 100m radius between 95 and 100m.

# %%
hc_sill = (47.75,237.26)
#hc_sill = (47.75,-122.74)
dabob_mouth = (47.69555,237.141)

dabob_sill_gap = (47.681, -122.87 + 360)
#dabob_sill_gap = (47.681, -122.87)


# o2.seed_elements(lon=hc_sill[1], 
#                 lat=hc_sill[0], 
#                 time=datetime(2024,3,2,0,0,),
#                 number=50, 
#                 radius=100)
o2.seed_elements(lon=dabob_sill_gap[1], 
                lat=dabob_sill_gap[0], 
                time=datetime(2024,4,9,0,0,),
                number=100, 
                radius=100,
                z=np.linspace(-95,-100,100)
                )
o2.seed_elements(lon=dabob_sill_gap[1], 
                lat=dabob_sill_gap[0], 
                time=datetime(2024,4,9,0,0,),
                number=100, 
                radius=100,
                z=np.linspace(-5,-10,100)
                )
o2.plot()
# Out:
# 13:49:58 INFO    opendrift.models.basemodel.environment:220: Adding a dynamical landmask with max. priority based on assumed maximum speed of 1.0 m/s. Adding a customised landmask may be faster...
# 13:50:02 INFO    opendrift.models.basemodel.environment:247: Fallback values will be used for the following variables which have no readers:
# 13:50:02 INFO    opendrift.models.basemodel.environment:250: 	x_wind: 0.000000
# 13:50:02 INFO    opendrift.models.basemodel.environment:250: 	y_wind: 0.000000
# 13:50:02 INFO    opendrift.models.basemodel.environment:250: 	ocean_vertical_diffusivity: 0.000000
# 13:50:02 INFO    opendrift.models.basemodel.environment:250: 	sea_surface_wave_significant_height: 0.000000
# 13:50:02 INFO    opendrift.models.basemodel.environment:250: 	sea_surface_wave_stokes_drift_x_velocity: 0.000000
# 13:50:02 INFO    opendrift.models.basemodel.environment:250: 	sea_surface_wave_stokes_drift_y_velocity: 0.000000
# 13:50:02 INFO    opendrift.models.basemodel.environment:250: 	sea_surface_wave_period_at_variance_spectral_density_maximum: 0.000000
# 13:50:02 INFO    opendrift.models.basemodel.environment:250: 	sea_surface_wave_mean_period_from_variance_spectral_density_second_frequency_moment: 0.000000
# 13:50:02 INFO    opendrift.models.basemodel.environment:250: 	sea_surface_swell_wave_to_direction: 0.000000
# 13:50:02 INFO    opendrift.models.basemodel.environment:250: 	sea_surface_swell_wave_peak_period_from_variance_spectral_density: 0.000000
# 13:50:02 INFO    opendrift.models.basemodel.environment:250: 	sea_surface_swell_wave_significant_height: 0.000000
# 13:50:02 INFO    opendrift.models.basemodel.environment:250: 	sea_surface_wind_wave_to_direction: 0.000000
# 13:50:02 INFO    opendrift.models.basemodel.environment:250: 	sea_surface_wind_wave_mean_period: 0.000000
# 13:50:02 INFO    opendrift.models.basemodel.environment:250: 	sea_surface_wind_wave_significant_height: 0.000000
# 13:50:02 INFO    opendrift.models.basemodel.environment:250: 	surface_downward_x_stress: 0.000000
# 13:50:02 INFO    opendrift.models.basemodel.environment:250: 	surface_downward_y_stress: 0.000000
# 13:50:02 INFO    opendrift.models.basemodel.environment:250: 	ocean_mixed_layer_thickness: 50.000000
# (<GeoAxes: title={'center': 'OpenDrift - OceanDrift\n200 elements seeded at 2024-04-09 00:00 UTC'}>,
#  <Figure size 1100x819.255 with 1 Axes>)

# %% [markdown]
# # Run opendrift and save output

# %%
o2.run(time_step=timedelta(minutes=10),
      duration=timedelta(hours=48),
      outfile='test_output_95_100.nc');
#o2.plot()
# Out:
# 13:51:26 INFO    opendrift.models.basemodel:891: Using existing reader for land_binary_mask
# 13:51:26 INFO    opendrift.models.basemodel:903: All points are in ocean
# 13:51:26 INFO    opendrift.readers.reader_ROMS_native:318: Using mask_rho for mask_rho
# 13:51:26 INFO    opendrift.models.basemodel:1992: 2024-04-09 00:00:00 - step 1 of 288 - 200 active elements (0 deactivated)
# 13:51:26 INFO    opendrift.readers.reader_ROMS_native:339: Using mask_u for mask_u
# 13:51:28 INFO    opendrift.readers.reader_ROMS_native:535: Time: 0:00:01.198662
# 13:51:28 INFO    opendrift.readers.reader_ROMS_native:360: Using mask_v for mask_v
# 13:51:28 INFO    opendrift.models.basemodel:1992: 2024-04-09 00:10:00 - step 2 of 288 - 200 active elements (0 deactivated)
# 13:51:28 INFO    opendrift.models.basemodel:1992: 2024-04-09 00:20:00 - step 3 of 288 - 200 active elements (0 deactivated)
# 13:51:29 INFO    opendrift.models.basemodel:1992: 2024-04-09 00:30:00 - step 4 of 288 - 200 active elements (0 deactivated)
# 13:51:29 INFO    opendrift.models.basemodel:1992: 2024-04-09 00:40:00 - step 5 of 288 - 200 active elements (0 deactivated)
# 13:51:29 INFO    opendrift.models.basemodel:1992: 2024-04-09 00:50:00 - step 6 of 288 - 200 active elements (0 deactivated)
# 13:51:29 INFO    opendrift.models.basemodel:1992: 2024-04-09 01:00:00 - step 7 of 288 - 200 active elements (0 deactivated)
# 13:51:29 INFO    opendrift.models.basemodel:1992: 2024-04-09 01:10:00 - step 8 of 288 - 200 active elements (0 deactivated)
# 13:51:29 INFO    opendrift.models.basemodel:1992: 2024-04-09 01:20:00 - step 9 of 288 - 200 active elements (0 deactivated)
# 13:51:29 INFO    opendrift.models.basemodel:1992: 2024-04-09 01:30:00 - step 10 of 288 - 200 active elements (0 deactivated)
# 13:51:29 INFO    opendrift.models.basemodel:1992: 2024-04-09 01:40:00 - step 11 of 288 - 200 active elements (0 deactivated)
# 13:51:29 INFO    opendrift.models.basemodel:1992: 2024-04-09 01:50:00 - step 12 of 288 - 200 active elements (0 deactivated)
# 13:51:29 INFO    opendrift.models.basemodel:1992: 2024-04-09 02:00:00 - step 13 of 288 - 200 active elements (0 deactivated)
# 13:51:29 INFO    opendrift.models.basemodel:1992: 2024-04-09 02:10:00 - step 14 of 288 - 200 active elements (0 deactivated)
# 13:51:30 INFO    opendrift.models.basemodel:1992: 2024-04-09 02:20:00 - step 15 of 288 - 200 active elements (0 deactivated)
# 13:51:30 INFO    opendrift.models.basemodel:1992: 2024-04-09 02:30:00 - step 16 of 288 - 200 active elements (0 deactivated)
# 13:51:30 INFO    opendrift.models.basemodel:1992: 2024-04-09 02:40:00 - step 17 of 288 - 200 active elements (0 deactivated)
# 13:51:30 INFO    opendrift.models.basemodel:1992: 2024-04-09 02:50:00 - step 18 of 288 - 200 active elements (0 deactivated)
# 13:51:30 INFO    opendrift.models.basemodel:1992: 2024-04-09 03:00:00 - step 19 of 288 - 200 active elements (0 deactivated)
# 13:51:30 INFO    opendrift.models.basemodel:1992: 2024-04-09 03:10:00 - step 20 of 288 - 200 active elements (0 deactivated)
# 13:51:30 INFO    opendrift.models.basemodel:1992: 2024-04-09 03:20:00 - step 21 of 288 - 200 active elements (0 deactivated)
# 13:51:30 INFO    opendrift.models.basemodel:1992: 2024-04-09 03:30:00 - step 22 of 288 - 200 active elements (0 deactivated)
# 13:51:30 INFO    opendrift.models.basemodel:1992: 2024-04-09 03:40:00 - step 23 of 288 - 200 active elements (0 deactivated)
# 13:51:30 INFO    opendrift.models.basemodel:1992: 2024-04-09 03:50:00 - step 24 of 288 - 200 active elements (0 deactivated)
# 13:51:30 INFO    opendrift.models.basemodel:1992: 2024-04-09 04:00:00 - step 25 of 288 - 200 active elements (0 deactivated)
# 13:51:30 INFO    opendrift.models.basemodel:1992: 2024-04-09 04:10:00 - step 26 of 288 - 200 active elements (0 deactivated)
# 13:51:31 INFO    opendrift.models.basemodel:1992: 2024-04-09 04:20:00 - step 27 of 288 - 200 active elements (0 deactivated)
# 13:51:31 INFO    opendrift.models.basemodel:1992: 2024-04-09 04:30:00 - step 28 of 288 - 200 active elements (0 deactivated)
# 13:51:31 INFO    opendrift.models.basemodel:1992: 2024-04-09 04:40:00 - step 29 of 288 - 200 active elements (0 deactivated)
# 13:51:31 INFO    opendrift.models.basemodel:1992: 2024-04-09 04:50:00 - step 30 of 288 - 200 active elements (0 deactivated)
# 13:51:31 INFO    opendrift.models.basemodel:1992: 2024-04-09 05:00:00 - step 31 of 288 - 200 active elements (0 deactivated)
# 13:51:31 INFO    opendrift.models.basemodel:1992: 2024-04-09 05:10:00 - step 32 of 288 - 200 active elements (0 deactivated)
# 13:51:31 INFO    opendrift.models.basemodel:1992: 2024-04-09 05:20:00 - step 33 of 288 - 200 active elements (0 deactivated)
# 13:51:31 INFO    opendrift.models.basemodel:1992: 2024-04-09 05:30:00 - step 34 of 288 - 196 active elements (4 deactivated)
# 13:51:31 INFO    opendrift.models.basemodel:1992: 2024-04-09 05:40:00 - step 35 of 288 - 192 active elements (8 deactivated)
# 13:51:31 INFO    opendrift.models.basemodel:1992: 2024-04-09 05:50:00 - step 36 of 288 - 190 active elements (10 deactivated)
# 13:51:32 INFO    opendrift.models.basemodel:1992: 2024-04-09 06:00:00 - step 37 of 288 - 190 active elements (10 deactivated)
# 13:51:32 INFO    opendrift.models.basemodel:1992: 2024-04-09 06:10:00 - step 38 of 288 - 190 active elements (10 deactivated)
# 13:51:32 INFO    opendrift.models.basemodel:1992: 2024-04-09 06:20:00 - step 39 of 288 - 190 active elements (10 deactivated)
# 13:51:32 INFO    opendrift.models.basemodel:1992: 2024-04-09 06:30:00 - step 40 of 288 - 190 active elements (10 deactivated)
# 13:51:32 INFO    opendrift.models.basemodel:1992: 2024-04-09 06:40:00 - step 41 of 288 - 190 active elements (10 deactivated)
# 13:51:32 INFO    opendrift.models.basemodel:1992: 2024-04-09 06:50:00 - step 42 of 288 - 189 active elements (11 deactivated)
# 13:51:32 INFO    opendrift.models.basemodel:1992: 2024-04-09 07:00:00 - step 43 of 288 - 188 active elements (12 deactivated)
# 13:51:32 INFO    opendrift.models.basemodel:1992: 2024-04-09 07:10:00 - step 44 of 288 - 186 active elements (14 deactivated)
# 13:51:33 INFO    opendrift.models.basemodel:1992: 2024-04-09 07:20:00 - step 45 of 288 - 186 active elements (14 deactivated)
# 13:51:33 INFO    opendrift.models.basemodel:1992: 2024-04-09 07:30:00 - step 46 of 288 - 186 active elements (14 deactivated)
# 13:51:33 INFO    opendrift.models.basemodel:1992: 2024-04-09 07:40:00 - step 47 of 288 - 186 active elements (14 deactivated)
# 13:51:33 INFO    opendrift.models.basemodel:1992: 2024-04-09 07:50:00 - step 48 of 288 - 186 active elements (14 deactivated)
# 13:51:33 INFO    opendrift.models.basemodel:1992: 2024-04-09 08:00:00 - step 49 of 288 - 186 active elements (14 deactivated)
# 13:51:33 INFO    opendrift.models.basemodel:1992: 2024-04-09 08:10:00 - step 50 of 288 - 185 active elements (15 deactivated)
# 13:51:33 INFO    opendrift.models.basemodel:1992: 2024-04-09 08:20:00 - step 51 of 288 - 185 active elements (15 deactivated)
# 13:51:33 INFO    opendrift.models.basemodel:1992: 2024-04-09 08:30:00 - step 52 of 288 - 184 active elements (16 deactivated)
# 13:51:33 INFO    opendrift.models.basemodel:1992: 2024-04-09 08:40:00 - step 53 of 288 - 183 active elements (17 deactivated)
# 13:51:33 INFO    opendrift.models.basemodel:1992: 2024-04-09 08:50:00 - step 54 of 288 - 183 active elements (17 deactivated)
# 13:51:33 INFO    opendrift.models.basemodel:1992: 2024-04-09 09:00:00 - step 55 of 288 - 183 active elements (17 deactivated)
# 13:51:33 INFO    opendrift.models.basemodel:1992: 2024-04-09 09:10:00 - step 56 of 288 - 183 active elements (17 deactivated)
# 13:51:34 INFO    opendrift.models.basemodel:1992: 2024-04-09 09:20:00 - step 57 of 288 - 183 active elements (17 deactivated)
# 13:51:34 INFO    opendrift.models.basemodel:1992: 2024-04-09 09:30:00 - step 58 of 288 - 183 active elements (17 deactivated)
# 13:51:34 INFO    opendrift.models.basemodel:1992: 2024-04-09 09:40:00 - step 59 of 288 - 183 active elements (17 deactivated)
# 13:51:34 INFO    opendrift.models.basemodel:1992: 2024-04-09 09:50:00 - step 60 of 288 - 183 active elements (17 deactivated)
# 13:51:34 INFO    opendrift.models.basemodel:1992: 2024-04-09 10:00:00 - step 61 of 288 - 183 active elements (17 deactivated)
# 13:51:34 INFO    opendrift.models.basemodel:1992: 2024-04-09 10:10:00 - step 62 of 288 - 183 active elements (17 deactivated)
# 13:51:34 INFO    opendrift.models.basemodel:1992: 2024-04-09 10:20:00 - step 63 of 288 - 183 active elements (17 deactivated)
# 13:51:35 INFO    opendrift.models.basemodel:1992: 2024-04-09 10:30:00 - step 64 of 288 - 183 active elements (17 deactivated)
# 13:51:35 INFO    opendrift.models.basemodel:1992: 2024-04-09 10:40:00 - step 65 of 288 - 183 active elements (17 deactivated)
# 13:51:35 INFO    opendrift.models.basemodel:1992: 2024-04-09 10:50:00 - step 66 of 288 - 183 active elements (17 deactivated)
# 13:51:35 INFO    opendrift.models.basemodel:1992: 2024-04-09 11:00:00 - step 67 of 288 - 183 active elements (17 deactivated)
# 13:51:35 INFO    opendrift.models.basemodel:1992: 2024-04-09 11:10:00 - step 68 of 288 - 183 active elements (17 deactivated)
# 13:51:35 INFO    opendrift.models.basemodel:1992: 2024-04-09 11:20:00 - step 69 of 288 - 183 active elements (17 deactivated)
# 13:51:35 INFO    opendrift.models.basemodel:1992: 2024-04-09 11:30:00 - step 70 of 288 - 183 active elements (17 deactivated)
# 13:51:35 INFO    opendrift.models.basemodel:1992: 2024-04-09 11:40:00 - step 71 of 288 - 183 active elements (17 deactivated)
# 13:51:35 INFO    opendrift.models.basemodel:1992: 2024-04-09 11:50:00 - step 72 of 288 - 183 active elements (17 deactivated)
# 13:51:35 INFO    opendrift.models.basemodel:1992: 2024-04-09 12:00:00 - step 73 of 288 - 183 active elements (17 deactivated)
# 13:51:35 INFO    opendrift.models.basemodel:1992: 2024-04-09 12:10:00 - step 74 of 288 - 183 active elements (17 deactivated)
# 13:51:36 INFO    opendrift.models.basemodel:1992: 2024-04-09 12:20:00 - step 75 of 288 - 183 active elements (17 deactivated)
# 13:51:36 INFO    opendrift.models.basemodel:1992: 2024-04-09 12:30:00 - step 76 of 288 - 183 active elements (17 deactivated)
# 13:51:36 INFO    opendrift.models.basemodel:1992: 2024-04-09 12:40:00 - step 77 of 288 - 183 active elements (17 deactivated)
# 13:51:36 INFO    opendrift.models.basemodel:1992: 2024-04-09 12:50:00 - step 78 of 288 - 183 active elements (17 deactivated)
# 13:51:36 INFO    opendrift.models.basemodel:1992: 2024-04-09 13:00:00 - step 79 of 288 - 183 active elements (17 deactivated)
# 13:51:36 INFO    opendrift.models.basemodel:1992: 2024-04-09 13:10:00 - step 80 of 288 - 183 active elements (17 deactivated)
# 13:51:36 INFO    opendrift.models.basemodel:1992: 2024-04-09 13:20:00 - step 81 of 288 - 183 active elements (17 deactivated)
# 13:51:36 INFO    opendrift.models.basemodel:1992: 2024-04-09 13:30:00 - step 82 of 288 - 183 active elements (17 deactivated)
# 13:51:37 INFO    opendrift.models.basemodel:1992: 2024-04-09 13:40:00 - step 83 of 288 - 183 active elements (17 deactivated)
# 13:51:37 INFO    opendrift.models.basemodel:1992: 2024-04-09 13:50:00 - step 84 of 288 - 183 active elements (17 deactivated)
# 13:51:37 INFO    opendrift.models.basemodel:1992: 2024-04-09 14:00:00 - step 85 of 288 - 182 active elements (18 deactivated)
# 13:51:37 INFO    opendrift.models.basemodel:1992: 2024-04-09 14:10:00 - step 86 of 288 - 182 active elements (18 deactivated)
# 13:51:37 INFO    opendrift.models.basemodel:1992: 2024-04-09 14:20:00 - step 87 of 288 - 182 active elements (18 deactivated)
# 13:51:37 INFO    opendrift.models.basemodel:1992: 2024-04-09 14:30:00 - step 88 of 288 - 182 active elements (18 deactivated)
# 13:51:37 INFO    opendrift.models.basemodel:1992: 2024-04-09 14:40:00 - step 89 of 288 - 182 active elements (18 deactivated)
# 13:51:37 INFO    opendrift.models.basemodel:1992: 2024-04-09 14:50:00 - step 90 of 288 - 182 active elements (18 deactivated)
# 13:51:37 INFO    opendrift.models.basemodel:1992: 2024-04-09 15:00:00 - step 91 of 288 - 182 active elements (18 deactivated)
# 13:51:37 INFO    opendrift.models.basemodel:1992: 2024-04-09 15:10:00 - step 92 of 288 - 182 active elements (18 deactivated)
# 13:51:38 INFO    opendrift.models.basemodel:1992: 2024-04-09 15:20:00 - step 93 of 288 - 182 active elements (18 deactivated)
# 13:51:38 INFO    opendrift.models.basemodel:1992: 2024-04-09 15:30:00 - step 94 of 288 - 182 active elements (18 deactivated)
# 13:51:38 INFO    opendrift.models.basemodel:1992: 2024-04-09 15:40:00 - step 95 of 288 - 182 active elements (18 deactivated)
# 13:51:38 INFO    opendrift.models.basemodel:1992: 2024-04-09 15:50:00 - step 96 of 288 - 182 active elements (18 deactivated)
# 13:51:38 INFO    opendrift.models.basemodel:1992: 2024-04-09 16:00:00 - step 97 of 288 - 182 active elements (18 deactivated)
# 13:51:38 INFO    opendrift.models.basemodel:1992: 2024-04-09 16:10:00 - step 98 of 288 - 182 active elements (18 deactivated)
# 13:51:38 INFO    opendrift.models.basemodel:1992: 2024-04-09 16:20:00 - step 99 of 288 - 182 active elements (18 deactivated)
# 13:51:38 INFO    opendrift.models.basemodel:1992: 2024-04-09 16:30:00 - step 100 of 288 - 182 active elements (18 deactivated)
# 13:51:38 INFO    opendrift.export.io_netcdf:112: Wrote 100 steps to file test_output_95_100.nc
# 13:51:39 INFO    opendrift.models.basemodel:1992: 2024-04-09 16:40:00 - step 101 of 288 - 182 active elements (18 deactivated)
# 13:51:39 INFO    opendrift.models.basemodel:1992: 2024-04-09 16:50:00 - step 102 of 288 - 182 active elements (18 deactivated)
# 13:51:39 INFO    opendrift.models.basemodel:1992: 2024-04-09 17:00:00 - step 103 of 288 - 182 active elements (18 deactivated)
# 13:51:39 INFO    opendrift.models.basemodel:1992: 2024-04-09 17:10:00 - step 104 of 288 - 182 active elements (18 deactivated)
# 13:51:39 INFO    opendrift.models.basemodel:1992: 2024-04-09 17:20:00 - step 105 of 288 - 182 active elements (18 deactivated)
# 13:51:39 INFO    opendrift.models.basemodel:1992: 2024-04-09 17:30:00 - step 106 of 288 - 182 active elements (18 deactivated)
# 13:51:39 INFO    opendrift.models.basemodel:1992: 2024-04-09 17:40:00 - step 107 of 288 - 182 active elements (18 deactivated)
# 13:51:39 INFO    opendrift.models.basemodel:1992: 2024-04-09 17:50:00 - step 108 of 288 - 182 active elements (18 deactivated)
# 13:51:39 INFO    opendrift.models.basemodel:1992: 2024-04-09 18:00:00 - step 109 of 288 - 182 active elements (18 deactivated)
# 13:51:39 INFO    opendrift.models.basemodel:1992: 2024-04-09 18:10:00 - step 110 of 288 - 182 active elements (18 deactivated)
# 13:51:40 INFO    opendrift.models.basemodel:1992: 2024-04-09 18:20:00 - step 111 of 288 - 182 active elements (18 deactivated)
# 13:51:40 INFO    opendrift.models.basemodel:1992: 2024-04-09 18:30:00 - step 112 of 288 - 182 active elements (18 deactivated)
# 13:51:40 INFO    opendrift.models.basemodel:1992: 2024-04-09 18:40:00 - step 113 of 288 - 182 active elements (18 deactivated)
# 13:51:40 INFO    opendrift.models.basemodel:1992: 2024-04-09 18:50:00 - step 114 of 288 - 182 active elements (18 deactivated)
# 13:51:40 INFO    opendrift.models.basemodel:1992: 2024-04-09 19:00:00 - step 115 of 288 - 182 active elements (18 deactivated)
# 13:51:40 INFO    opendrift.models.basemodel:1992: 2024-04-09 19:10:00 - step 116 of 288 - 182 active elements (18 deactivated)
# 13:51:40 INFO    opendrift.models.basemodel:1992: 2024-04-09 19:20:00 - step 117 of 288 - 182 active elements (18 deactivated)
# 13:51:40 INFO    opendrift.models.basemodel:1992: 2024-04-09 19:30:00 - step 118 of 288 - 182 active elements (18 deactivated)
# 13:51:40 INFO    opendrift.models.basemodel:1992: 2024-04-09 19:40:00 - step 119 of 288 - 182 active elements (18 deactivated)
# 13:51:40 INFO    opendrift.models.basemodel:1992: 2024-04-09 19:50:00 - step 120 of 288 - 182 active elements (18 deactivated)
# 13:51:41 INFO    opendrift.models.basemodel:1992: 2024-04-09 20:00:00 - step 121 of 288 - 182 active elements (18 deactivated)
# 13:51:41 INFO    opendrift.models.basemodel:1992: 2024-04-09 20:10:00 - step 122 of 288 - 182 active elements (18 deactivated)
# 13:51:41 INFO    opendrift.models.basemodel:1992: 2024-04-09 20:20:00 - step 123 of 288 - 182 active elements (18 deactivated)
# 13:51:41 INFO    opendrift.models.basemodel:1992: 2024-04-09 20:30:00 - step 124 of 288 - 182 active elements (18 deactivated)
# 13:51:41 INFO    opendrift.models.basemodel:1992: 2024-04-09 20:40:00 - step 125 of 288 - 182 active elements (18 deactivated)
# 13:51:41 INFO    opendrift.models.basemodel:1992: 2024-04-09 20:50:00 - step 126 of 288 - 182 active elements (18 deactivated)
# 13:51:41 INFO    opendrift.models.basemodel:1992: 2024-04-09 21:00:00 - step 127 of 288 - 182 active elements (18 deactivated)
# 13:51:41 INFO    opendrift.models.basemodel:1992: 2024-04-09 21:10:00 - step 128 of 288 - 182 active elements (18 deactivated)
# 13:51:42 INFO    opendrift.models.basemodel:1992: 2024-04-09 21:20:00 - step 129 of 288 - 182 active elements (18 deactivated)
# 13:51:42 INFO    opendrift.models.basemodel:1992: 2024-04-09 21:30:00 - step 130 of 288 - 182 active elements (18 deactivated)
# 13:51:42 INFO    opendrift.models.basemodel:1992: 2024-04-09 21:40:00 - step 131 of 288 - 182 active elements (18 deactivated)
# 13:51:42 INFO    opendrift.models.basemodel:1992: 2024-04-09 21:50:00 - step 132 of 288 - 182 active elements (18 deactivated)
# 13:51:42 INFO    opendrift.models.basemodel:1992: 2024-04-09 22:00:00 - step 133 of 288 - 182 active elements (18 deactivated)
# 13:51:42 INFO    opendrift.models.basemodel:1992: 2024-04-09 22:10:00 - step 134 of 288 - 182 active elements (18 deactivated)
# 13:51:42 INFO    opendrift.models.basemodel:1992: 2024-04-09 22:20:00 - step 135 of 288 - 182 active elements (18 deactivated)
# 13:51:42 INFO    opendrift.models.basemodel:1992: 2024-04-09 22:30:00 - step 136 of 288 - 182 active elements (18 deactivated)
# 13:51:42 INFO    opendrift.models.basemodel:1992: 2024-04-09 22:40:00 - step 137 of 288 - 182 active elements (18 deactivated)
# 13:51:42 INFO    opendrift.models.basemodel:1992: 2024-04-09 22:50:00 - step 138 of 288 - 182 active elements (18 deactivated)
# 13:51:42 INFO    opendrift.models.basemodel:1992: 2024-04-09 23:00:00 - step 139 of 288 - 182 active elements (18 deactivated)
# 13:51:43 INFO    opendrift.models.basemodel:1992: 2024-04-09 23:10:00 - step 140 of 288 - 182 active elements (18 deactivated)
# 13:51:43 INFO    opendrift.models.basemodel:1992: 2024-04-09 23:20:00 - step 141 of 288 - 182 active elements (18 deactivated)
# 13:51:43 INFO    opendrift.models.basemodel:1992: 2024-04-09 23:30:00 - step 142 of 288 - 182 active elements (18 deactivated)
# 13:51:43 INFO    opendrift.models.basemodel:1992: 2024-04-09 23:40:00 - step 143 of 288 - 182 active elements (18 deactivated)
# 13:51:43 INFO    opendrift.models.basemodel:1992: 2024-04-09 23:50:00 - step 144 of 288 - 182 active elements (18 deactivated)
# 13:51:43 INFO    opendrift.models.basemodel:1992: 2024-04-10 00:00:00 - step 145 of 288 - 182 active elements (18 deactivated)
# 13:51:43 INFO    opendrift.models.basemodel:1992: 2024-04-10 00:10:00 - step 146 of 288 - 182 active elements (18 deactivated)
# 13:51:44 INFO    opendrift.models.basemodel:1992: 2024-04-10 00:20:00 - step 147 of 288 - 182 active elements (18 deactivated)
# 13:51:44 INFO    opendrift.models.basemodel:1992: 2024-04-10 00:30:00 - step 148 of 288 - 182 active elements (18 deactivated)
# 13:51:44 INFO    opendrift.models.basemodel:1992: 2024-04-10 00:40:00 - step 149 of 288 - 182 active elements (18 deactivated)
# 13:51:44 INFO    opendrift.models.basemodel:1992: 2024-04-10 00:50:00 - step 150 of 288 - 182 active elements (18 deactivated)
# 13:51:44 INFO    opendrift.models.basemodel:1992: 2024-04-10 01:00:00 - step 151 of 288 - 182 active elements (18 deactivated)
# 13:51:44 INFO    opendrift.models.basemodel:1992: 2024-04-10 01:10:00 - step 152 of 288 - 182 active elements (18 deactivated)
# 13:51:44 INFO    opendrift.models.basemodel:1992: 2024-04-10 01:20:00 - step 153 of 288 - 182 active elements (18 deactivated)
# 13:51:44 INFO    opendrift.models.basemodel:1992: 2024-04-10 01:30:00 - step 154 of 288 - 182 active elements (18 deactivated)
# 13:51:44 INFO    opendrift.models.basemodel:1992: 2024-04-10 01:40:00 - step 155 of 288 - 182 active elements (18 deactivated)
# 13:51:44 INFO    opendrift.models.basemodel:1992: 2024-04-10 01:50:00 - step 156 of 288 - 182 active elements (18 deactivated)
# 13:51:44 INFO    opendrift.models.basemodel:1992: 2024-04-10 02:00:00 - step 157 of 288 - 182 active elements (18 deactivated)
# 13:51:44 INFO    opendrift.models.basemodel:1992: 2024-04-10 02:10:00 - step 158 of 288 - 182 active elements (18 deactivated)
# 13:51:45 INFO    opendrift.models.basemodel:1992: 2024-04-10 02:20:00 - step 159 of 288 - 178 active elements (22 deactivated)
# 13:51:45 INFO    opendrift.models.basemodel:1992: 2024-04-10 02:30:00 - step 160 of 288 - 177 active elements (23 deactivated)
# 13:51:45 INFO    opendrift.models.basemodel:1992: 2024-04-10 02:40:00 - step 161 of 288 - 176 active elements (24 deactivated)
# 13:51:45 INFO    opendrift.models.basemodel:1992: 2024-04-10 02:50:00 - step 162 of 288 - 174 active elements (26 deactivated)
# 13:51:45 INFO    opendrift.models.basemodel:1992: 2024-04-10 03:00:00 - step 163 of 288 - 172 active elements (28 deactivated)
# 13:51:45 INFO    opendrift.models.basemodel:1992: 2024-04-10 03:10:00 - step 164 of 288 - 171 active elements (29 deactivated)
# 13:51:46 INFO    opendrift.models.basemodel:1992: 2024-04-10 03:20:00 - step 165 of 288 - 168 active elements (32 deactivated)
# 13:51:46 INFO    opendrift.models.basemodel:1992: 2024-04-10 03:30:00 - step 166 of 288 - 164 active elements (36 deactivated)
# 13:51:46 INFO    opendrift.models.basemodel:1992: 2024-04-10 03:40:00 - step 167 of 288 - 162 active elements (38 deactivated)
# 13:51:46 INFO    opendrift.models.basemodel:1992: 2024-04-10 03:50:00 - step 168 of 288 - 162 active elements (38 deactivated)
# 13:51:46 INFO    opendrift.models.basemodel:1992: 2024-04-10 04:00:00 - step 169 of 288 - 159 active elements (41 deactivated)
# 13:51:46 INFO    opendrift.models.basemodel:1992: 2024-04-10 04:10:00 - step 170 of 288 - 158 active elements (42 deactivated)
# 13:51:46 INFO    opendrift.models.basemodel:1992: 2024-04-10 04:20:00 - step 171 of 288 - 157 active elements (43 deactivated)
# 13:51:46 INFO    opendrift.models.basemodel:1992: 2024-04-10 04:30:00 - step 172 of 288 - 157 active elements (43 deactivated)
# 13:51:46 INFO    opendrift.models.basemodel:1992: 2024-04-10 04:40:00 - step 173 of 288 - 156 active elements (44 deactivated)
# 13:51:46 INFO    opendrift.models.basemodel:1992: 2024-04-10 04:50:00 - step 174 of 288 - 156 active elements (44 deactivated)
# 13:51:46 INFO    opendrift.models.basemodel:1992: 2024-04-10 05:00:00 - step 175 of 288 - 156 active elements (44 deactivated)
# 13:51:46 INFO    opendrift.models.basemodel:1992: 2024-04-10 05:10:00 - step 176 of 288 - 155 active elements (45 deactivated)
# 13:51:47 INFO    opendrift.models.basemodel:1992: 2024-04-10 05:20:00 - step 177 of 288 - 155 active elements (45 deactivated)
# 13:51:47 INFO    opendrift.models.basemodel:1992: 2024-04-10 05:30:00 - step 178 of 288 - 155 active elements (45 deactivated)
# 13:51:47 INFO    opendrift.models.basemodel:1992: 2024-04-10 05:40:00 - step 179 of 288 - 155 active elements (45 deactivated)
# 13:51:47 INFO    opendrift.models.basemodel:1992: 2024-04-10 05:50:00 - step 180 of 288 - 155 active elements (45 deactivated)
# 13:51:47 INFO    opendrift.models.basemodel:1992: 2024-04-10 06:00:00 - step 181 of 288 - 155 active elements (45 deactivated)
# 13:51:47 INFO    opendrift.models.basemodel:1992: 2024-04-10 06:10:00 - step 182 of 288 - 154 active elements (46 deactivated)
# 13:51:48 INFO    opendrift.models.basemodel:1992: 2024-04-10 06:20:00 - step 183 of 288 - 154 active elements (46 deactivated)
# 13:51:48 INFO    opendrift.models.basemodel:1992: 2024-04-10 06:30:00 - step 184 of 288 - 153 active elements (47 deactivated)
# 13:51:48 INFO    opendrift.models.basemodel:1992: 2024-04-10 06:40:00 - step 185 of 288 - 153 active elements (47 deactivated)
# 13:51:48 INFO    opendrift.models.basemodel:1992: 2024-04-10 06:50:00 - step 186 of 288 - 153 active elements (47 deactivated)
# 13:51:48 INFO    opendrift.models.basemodel:1992: 2024-04-10 07:00:00 - step 187 of 288 - 153 active elements (47 deactivated)
# 13:51:48 INFO    opendrift.models.basemodel:1992: 2024-04-10 07:10:00 - step 188 of 288 - 153 active elements (47 deactivated)
# 13:51:48 INFO    opendrift.models.basemodel:1992: 2024-04-10 07:20:00 - step 189 of 288 - 153 active elements (47 deactivated)
# 13:51:48 INFO    opendrift.models.basemodel:1992: 2024-04-10 07:30:00 - step 190 of 288 - 153 active elements (47 deactivated)
# 13:51:48 INFO    opendrift.models.basemodel:1992: 2024-04-10 07:40:00 - step 191 of 288 - 153 active elements (47 deactivated)
# 13:51:48 INFO    opendrift.models.basemodel:1992: 2024-04-10 07:50:00 - step 192 of 288 - 153 active elements (47 deactivated)
# 13:51:48 INFO    opendrift.models.basemodel:1992: 2024-04-10 08:00:00 - step 193 of 288 - 153 active elements (47 deactivated)
# 13:51:48 INFO    opendrift.models.basemodel:1992: 2024-04-10 08:10:00 - step 194 of 288 - 153 active elements (47 deactivated)
# 13:51:49 INFO    opendrift.models.basemodel:1992: 2024-04-10 08:20:00 - step 195 of 288 - 153 active elements (47 deactivated)
# 13:51:49 INFO    opendrift.models.basemodel:1992: 2024-04-10 08:30:00 - step 196 of 288 - 153 active elements (47 deactivated)
# 13:51:49 INFO    opendrift.models.basemodel:1992: 2024-04-10 08:40:00 - step 197 of 288 - 153 active elements (47 deactivated)
# 13:51:49 INFO    opendrift.models.basemodel:1992: 2024-04-10 08:50:00 - step 198 of 288 - 153 active elements (47 deactivated)
# 13:51:49 INFO    opendrift.models.basemodel:1992: 2024-04-10 09:00:00 - step 199 of 288 - 153 active elements (47 deactivated)
# 13:51:49 INFO    opendrift.models.basemodel:1992: 2024-04-10 09:10:00 - step 200 of 288 - 153 active elements (47 deactivated)
# 13:51:50 INFO    opendrift.export.io_netcdf:112: Wrote 100 steps to file test_output_95_100.nc
# 13:51:50 INFO    opendrift.models.basemodel:1992: 2024-04-10 09:20:00 - step 201 of 288 - 152 active elements (48 deactivated)
# 13:51:50 INFO    opendrift.models.basemodel:1992: 2024-04-10 09:30:00 - step 202 of 288 - 152 active elements (48 deactivated)
# 13:51:50 INFO    opendrift.models.basemodel:1992: 2024-04-10 09:40:00 - step 203 of 288 - 151 active elements (49 deactivated)
# 13:51:50 INFO    opendrift.models.basemodel:1992: 2024-04-10 09:50:00 - step 204 of 288 - 151 active elements (49 deactivated)
# 13:51:50 INFO    opendrift.models.basemodel:1992: 2024-04-10 10:00:00 - step 205 of 288 - 151 active elements (49 deactivated)
# 13:51:50 INFO    opendrift.models.basemodel:1992: 2024-04-10 10:10:00 - step 206 of 288 - 151 active elements (49 deactivated)
# 13:51:51 INFO    opendrift.models.basemodel:1992: 2024-04-10 10:20:00 - step 207 of 288 - 151 active elements (49 deactivated)
# 13:51:51 INFO    opendrift.models.basemodel:1992: 2024-04-10 10:30:00 - step 208 of 288 - 151 active elements (49 deactivated)
# 13:51:51 INFO    opendrift.models.basemodel:1992: 2024-04-10 10:40:00 - step 209 of 288 - 151 active elements (49 deactivated)
# 13:51:51 INFO    opendrift.models.basemodel:1992: 2024-04-10 10:50:00 - step 210 of 288 - 151 active elements (49 deactivated)
# 13:51:51 INFO    opendrift.models.basemodel:1992: 2024-04-10 11:00:00 - step 211 of 288 - 151 active elements (49 deactivated)
# 13:51:51 INFO    opendrift.models.basemodel:1992: 2024-04-10 11:10:00 - step 212 of 288 - 151 active elements (49 deactivated)
# 13:51:51 INFO    opendrift.models.basemodel:1992: 2024-04-10 11:20:00 - step 213 of 288 - 151 active elements (49 deactivated)
# 13:51:51 INFO    opendrift.models.basemodel:1992: 2024-04-10 11:30:00 - step 214 of 288 - 151 active elements (49 deactivated)
# 13:51:51 INFO    opendrift.models.basemodel:1992: 2024-04-10 11:40:00 - step 215 of 288 - 151 active elements (49 deactivated)
# 13:51:52 INFO    opendrift.models.basemodel:1992: 2024-04-10 11:50:00 - step 216 of 288 - 151 active elements (49 deactivated)
# 13:51:52 INFO    opendrift.models.basemodel:1992: 2024-04-10 12:00:00 - step 217 of 288 - 151 active elements (49 deactivated)
# 13:51:52 INFO    opendrift.models.basemodel:1992: 2024-04-10 12:10:00 - step 218 of 288 - 151 active elements (49 deactivated)
# 13:51:52 INFO    opendrift.models.basemodel:1992: 2024-04-10 12:20:00 - step 219 of 288 - 151 active elements (49 deactivated)
# 13:51:52 INFO    opendrift.models.basemodel:1992: 2024-04-10 12:30:00 - step 220 of 288 - 151 active elements (49 deactivated)
# 13:51:52 INFO    opendrift.models.basemodel:1992: 2024-04-10 12:40:00 - step 221 of 288 - 151 active elements (49 deactivated)
# 13:51:52 INFO    opendrift.models.basemodel:1992: 2024-04-10 12:50:00 - step 222 of 288 - 151 active elements (49 deactivated)
# 13:51:52 INFO    opendrift.models.basemodel:1992: 2024-04-10 13:00:00 - step 223 of 288 - 151 active elements (49 deactivated)
# 13:51:52 INFO    opendrift.models.basemodel:1992: 2024-04-10 13:10:00 - step 224 of 288 - 151 active elements (49 deactivated)
# 13:51:53 INFO    opendrift.models.basemodel:1992: 2024-04-10 13:20:00 - step 225 of 288 - 151 active elements (49 deactivated)
# 13:51:53 INFO    opendrift.models.basemodel:1992: 2024-04-10 13:30:00 - step 226 of 288 - 151 active elements (49 deactivated)
# 13:51:53 INFO    opendrift.models.basemodel:1992: 2024-04-10 13:40:00 - step 227 of 288 - 151 active elements (49 deactivated)
# 13:51:53 INFO    opendrift.models.basemodel:1992: 2024-04-10 13:50:00 - step 228 of 288 - 150 active elements (50 deactivated)
# 13:51:53 INFO    opendrift.models.basemodel:1992: 2024-04-10 14:00:00 - step 229 of 288 - 150 active elements (50 deactivated)
# 13:51:53 INFO    opendrift.models.basemodel:1992: 2024-04-10 14:10:00 - step 230 of 288 - 150 active elements (50 deactivated)
# 13:51:54 INFO    opendrift.models.basemodel:1992: 2024-04-10 14:20:00 - step 231 of 288 - 150 active elements (50 deactivated)
# 13:51:54 INFO    opendrift.models.basemodel:1992: 2024-04-10 14:30:00 - step 232 of 288 - 150 active elements (50 deactivated)
# 13:51:54 INFO    opendrift.models.basemodel:1992: 2024-04-10 14:40:00 - step 233 of 288 - 150 active elements (50 deactivated)
# 13:51:54 INFO    opendrift.models.basemodel:1992: 2024-04-10 14:50:00 - step 234 of 288 - 150 active elements (50 deactivated)
# 13:51:54 INFO    opendrift.models.basemodel:1992: 2024-04-10 15:00:00 - step 235 of 288 - 150 active elements (50 deactivated)
# 13:51:54 INFO    opendrift.models.basemodel:1992: 2024-04-10 15:10:00 - step 236 of 288 - 150 active elements (50 deactivated)
# 13:51:54 INFO    opendrift.models.basemodel:1992: 2024-04-10 15:20:00 - step 237 of 288 - 150 active elements (50 deactivated)
# 13:51:55 INFO    opendrift.models.basemodel:1992: 2024-04-10 15:30:00 - step 238 of 288 - 150 active elements (50 deactivated)
# 13:51:55 INFO    opendrift.models.basemodel:1992: 2024-04-10 15:40:00 - step 239 of 288 - 150 active elements (50 deactivated)
# 13:51:55 INFO    opendrift.models.basemodel:1992: 2024-04-10 15:50:00 - step 240 of 288 - 150 active elements (50 deactivated)
# 13:51:55 INFO    opendrift.models.basemodel:1992: 2024-04-10 16:00:00 - step 241 of 288 - 150 active elements (50 deactivated)
# 13:51:55 INFO    opendrift.models.basemodel:1992: 2024-04-10 16:10:00 - step 242 of 288 - 150 active elements (50 deactivated)
# 13:51:55 INFO    opendrift.models.basemodel:1992: 2024-04-10 16:20:00 - step 243 of 288 - 150 active elements (50 deactivated)
# 13:51:55 INFO    opendrift.models.basemodel:1992: 2024-04-10 16:30:00 - step 244 of 288 - 150 active elements (50 deactivated)
# 13:51:55 INFO    opendrift.models.basemodel:1992: 2024-04-10 16:40:00 - step 245 of 288 - 150 active elements (50 deactivated)
# 13:51:55 INFO    opendrift.models.basemodel:1992: 2024-04-10 16:50:00 - step 246 of 288 - 150 active elements (50 deactivated)
# 13:51:55 INFO    opendrift.models.basemodel:1992: 2024-04-10 17:00:00 - step 247 of 288 - 150 active elements (50 deactivated)
# 13:51:55 INFO    opendrift.models.basemodel:1992: 2024-04-10 17:10:00 - step 248 of 288 - 150 active elements (50 deactivated)
# 13:51:56 INFO    opendrift.models.basemodel:1992: 2024-04-10 17:20:00 - step 249 of 288 - 150 active elements (50 deactivated)
# 13:51:56 INFO    opendrift.models.basemodel:1992: 2024-04-10 17:30:00 - step 250 of 288 - 149 active elements (51 deactivated)
# 13:51:56 INFO    opendrift.models.basemodel:1992: 2024-04-10 17:40:00 - step 251 of 288 - 149 active elements (51 deactivated)
# 13:51:56 INFO    opendrift.models.basemodel:1992: 2024-04-10 17:50:00 - step 252 of 288 - 149 active elements (51 deactivated)
# 13:51:56 INFO    opendrift.models.basemodel:1992: 2024-04-10 18:00:00 - step 253 of 288 - 149 active elements (51 deactivated)
# 13:51:56 INFO    opendrift.models.basemodel:1992: 2024-04-10 18:10:00 - step 254 of 288 - 149 active elements (51 deactivated)
# 13:51:57 INFO    opendrift.models.basemodel:1992: 2024-04-10 18:20:00 - step 255 of 288 - 149 active elements (51 deactivated)
# 13:51:57 INFO    opendrift.models.basemodel:1992: 2024-04-10 18:30:00 - step 256 of 288 - 149 active elements (51 deactivated)
# 13:51:57 INFO    opendrift.models.basemodel:1992: 2024-04-10 18:40:00 - step 257 of 288 - 149 active elements (51 deactivated)
# 13:51:57 INFO    opendrift.models.basemodel:1992: 2024-04-10 18:50:00 - step 258 of 288 - 149 active elements (51 deactivated)
# 13:51:57 INFO    opendrift.models.basemodel:1992: 2024-04-10 19:00:00 - step 259 of 288 - 149 active elements (51 deactivated)
# 13:51:57 INFO    opendrift.models.basemodel:1992: 2024-04-10 19:10:00 - step 260 of 288 - 149 active elements (51 deactivated)
# 13:51:58 INFO    opendrift.models.basemodel:1992: 2024-04-10 19:20:00 - step 261 of 288 - 149 active elements (51 deactivated)
# 13:51:58 INFO    opendrift.models.basemodel:1992: 2024-04-10 19:30:00 - step 262 of 288 - 149 active elements (51 deactivated)
# 13:51:58 INFO    opendrift.models.basemodel:1992: 2024-04-10 19:40:00 - step 263 of 288 - 149 active elements (51 deactivated)
# 13:51:58 INFO    opendrift.models.basemodel:1992: 2024-04-10 19:50:00 - step 264 of 288 - 149 active elements (51 deactivated)
# 13:51:58 INFO    opendrift.models.basemodel:1992: 2024-04-10 20:00:00 - step 265 of 288 - 149 active elements (51 deactivated)
# 13:51:58 INFO    opendrift.models.basemodel:1992: 2024-04-10 20:10:00 - step 266 of 288 - 149 active elements (51 deactivated)
# 13:51:58 INFO    opendrift.models.basemodel:1992: 2024-04-10 20:20:00 - step 267 of 288 - 149 active elements (51 deactivated)
# 13:51:58 INFO    opendrift.models.basemodel:1992: 2024-04-10 20:30:00 - step 268 of 288 - 149 active elements (51 deactivated)
# 13:51:58 INFO    opendrift.models.basemodel:1992: 2024-04-10 20:40:00 - step 269 of 288 - 149 active elements (51 deactivated)
# 13:51:58 INFO    opendrift.models.basemodel:1992: 2024-04-10 20:50:00 - step 270 of 288 - 149 active elements (51 deactivated)
# 13:51:58 INFO    opendrift.models.basemodel:1992: 2024-04-10 21:00:00 - step 271 of 288 - 149 active elements (51 deactivated)
# 13:51:58 INFO    opendrift.models.basemodel:1992: 2024-04-10 21:10:00 - step 272 of 288 - 149 active elements (51 deactivated)
# 13:51:59 INFO    opendrift.models.basemodel:1992: 2024-04-10 21:20:00 - step 273 of 288 - 148 active elements (52 deactivated)
# 13:51:59 INFO    opendrift.models.basemodel:1992: 2024-04-10 21:30:00 - step 274 of 288 - 148 active elements (52 deactivated)
# 13:51:59 INFO    opendrift.models.basemodel:1992: 2024-04-10 21:40:00 - step 275 of 288 - 148 active elements (52 deactivated)
# 13:51:59 INFO    opendrift.models.basemodel:1992: 2024-04-10 21:50:00 - step 276 of 288 - 148 active elements (52 deactivated)
# 13:51:59 INFO    opendrift.models.basemodel:1992: 2024-04-10 22:00:00 - step 277 of 288 - 148 active elements (52 deactivated)
# 13:51:59 INFO    opendrift.models.basemodel:1992: 2024-04-10 22:10:00 - step 278 of 288 - 148 active elements (52 deactivated)
# 13:52:00 INFO    opendrift.models.basemodel:1992: 2024-04-10 22:20:00 - step 279 of 288 - 148 active elements (52 deactivated)
# 13:52:00 INFO    opendrift.models.basemodel:1992: 2024-04-10 22:30:00 - step 280 of 288 - 148 active elements (52 deactivated)
# 13:52:00 INFO    opendrift.models.basemodel:1992: 2024-04-10 22:40:00 - step 281 of 288 - 147 active elements (53 deactivated)
# 13:52:00 INFO    opendrift.models.basemodel:1992: 2024-04-10 22:50:00 - step 282 of 288 - 147 active elements (53 deactivated)
# 13:52:00 INFO    opendrift.models.basemodel:1992: 2024-04-10 23:00:00 - step 283 of 288 - 146 active elements (54 deactivated)
# 13:52:00 INFO    opendrift.models.basemodel:1992: 2024-04-10 23:10:00 - step 284 of 288 - 146 active elements (54 deactivated)
# 13:52:01 INFO    opendrift.models.basemodel:1992: 2024-04-10 23:20:00 - step 285 of 288 - 146 active elements (54 deactivated)
# 13:52:01 INFO    opendrift.models.basemodel:1992: 2024-04-10 23:30:00 - step 286 of 288 - 146 active elements (54 deactivated)
# 13:52:01 INFO    opendrift.models.basemodel:1992: 2024-04-10 23:40:00 - step 287 of 288 - 146 active elements (54 deactivated)
# 13:52:01 INFO    opendrift.models.basemodel:1992: 2024-04-10 23:50:00 - step 288 of 288 - 146 active elements (54 deactivated)
# 13:52:01 INFO    opendrift.export.io_netcdf:112: Wrote 89 steps to file test_output_95_100.nc

# %%
o2.plot(linecolor='z',alpha=0.3)
# Out:
# (<GeoAxes: title={'center': 'OpenDrift - OceanDrift\n2024-04-09 00:00 to 2024-04-11 00:00 UTC (289 steps)'}>,
#  <Figure size 1100x870.51 with 2 Axes>)

# %% [markdown]
# # Read drifter locations back in to xarray, filter out bad depths

# %%
test_out = xr.open_dataset('test_output_95_100.nc')
# !ls '../../pisces-dabob-vis/data/'
# Out:
# external  interim  processed  raw

# %%
test_out2 = test_out.where(test_out.z <0)

# %% [markdown]
# # Plot deep (first 100) and shallow (last 100) drifter particles

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
import cmocean
import cartopy.crs as ccrs
import cartopy.io.img_tiles as cimgt
from cartopy.mpl.ticker import LatitudeFormatter, LongitudeFormatter
import matplotlib.ticker as mticker

# Add google background to map
stamen_terrain = cimgt.GoogleTiles()

# zoom in for Aug field work
(ll_lat, ll_lon) = ( 47.64, -122.95)
(ur_lat, ur_lon) = ( 47.8, -122.65)

# Create colorbar limits
norm = mpl.colors.Normalize(vmin=-100,vmax=0)

# Create figure
fig = plt.figure(figsize=(11,8))

# Create Subplots, surface floats on left. Use Google map projection
ax1 = plt.subplot(1,2,1,projection=ccrs.Mercator())
ax2 = plt.subplot(1,2,2,projection=ccrs.Mercator())

# Plot deep drifters
ax2.add_image(stamen_terrain, 13)
ax2.scatter(test_out2['lon'][0:99,:],test_out2['lat'][0:99,:],
            c=test_out2['z'][0:99,:], 
            cmap='jet',
            norm=norm,
            alpha=0.3,
            transform=ccrs.PlateCarree())
ax2.plot(dabob_mouth[1],dabob_mouth[0],
         'o',
         markerfacecolor='white',
         markeredgecolor='blue',
         markersize=10,
         transform=ccrs.PlateCarree())
ax2.set_xlim(-122.95,-122.6)

# Limit the extent of the map to a small longitude/latitude range.
ax2.set_extent([ll_lon, ur_lon, ll_lat, ur_lat], crs=ccrs.Geodetic())
gl2 = ax2.gridlines(draw_labels=True, dms=True, alpha=0.2,x_inline=False, y_inline=False)

# remove labels on left side of plot so it doesn't conflict with the shallow plot
gl2.left_labels = []
ax2.set_title('Deep Release, 95-100m')


# Plot shallow drifters
ax1.add_image(stamen_terrain, 13)
ax1.scatter(test_out2['lon'][100:199,:],test_out2['lat'][100:199,:],
            c=test_out2['z'][100:199,:],
            cmap='jet',
            norm=norm,
            alpha=0.3,
            transform=ccrs.PlateCarree())
ax1.plot(dabob_mouth[1],dabob_mouth[0],
         'o',
         markerfacecolor='white',
         markeredgecolor='blue',
         markersize=10,
         transform=ccrs.PlateCarree())

# Limit the extent of the map to a small longitude/latitude range.
ax1.set_extent([ll_lon, ur_lon, ll_lat, ur_lat], crs=ccrs.Geodetic())
gl1 = ax1.gridlines(draw_labels=True, dms=True, alpha=0.2,x_inline=False, y_inline=False)
gl1.right_labels = []
ax1.set_title('Shallow Release, 5-10m')

# Add Colorbar
cbaxes = fig.add_axes([0.4, 0.2, 0.2, 0.02]) 
cb=plt.colorbar(mpl.cm.ScalarMappable(norm=norm, cmap='jet'),
                cax=cbaxes, 
                orientation='horizontal',
                extend='both', 
                label='Drifter Depth (m)'
               )
cbaxes.set_zorder(5)
