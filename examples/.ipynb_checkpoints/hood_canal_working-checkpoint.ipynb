# %%
# from datetime import datetime, timedelta
# from opendrift.models.oceandrift import OceanDrift

# # Basic ocean drift module: current + 2% of wind
# o = OceanDrift(loglevel=20)

# # Adding readers for global Thredds datasets:
# # - Ocean forecast from global HYCOM model
# # - Weather forecast from NOAA/NCEP
# o.add_readers_from_list([
#     '/import/c1/VERTMIX/jgpender/coawst/HC_100m_30layers/Experiments/HC_100m_2024.02.29/netcdfOutput/hc_his_00062.nc'
#     'https://tds.hycom.org/thredds/dodsC/GLBy0.08/latest',
#     'https://pae-paha.pacioos.hawaii.edu/thredds/dodsC/ncep_global/NCEP_Global_Atmospheric_Model_best.ncd'])

# o.seed_elements(lat=24, lon=-81, time=datetime.utcnow(),
#                 number=5000, radius=10000)

# o.run(time_step=timedelta(minutes=30),
#       duration=timedelta(days=5))
# o.animation()

# %%
from datetime import datetime, timedelta
from opendrift.models.oceandrift import OceanDrift
from opendrift.readers import reader_ROMS_native
import xarray as xr

#from opendrift.readers.reader_ROMS_native import Reader
        # ds = xr.open_dataset(filename, decode_times=False)
        # r = Reader(ds)

o2=[]
# Basic ocean drift module: current + 2% of wind
o2 = OceanDrift(loglevel=20)
# Out:
# 17:14:32 INFO    opendrift.models.basemodel:528: OpenDriftSimulation initialised (version 1.11.1 / v1.11.1-26-gc27e2f6-dirty)

# %%
#o2.set_config('general:coastline_action', 'none')
#o2.set_config('general:use_auto_landmask', False)
# Adding readers for global Thredds datasets:
# - Ocean forecast from global HYCOM model
# - Weather forecast from NOAA/NCEP

netCDFs = '/import/c1/VERTMIX/jgpender/coawst/HC_100m_30layers/Experiments/HC_100m_2024.03.01/netcdfOutput/hc_his_*.nc'
grid = '/import/c1/VERTMIX/jgpender/coawst/HC_100m_30layers/Experiments/HC_100m_2024.03.01/HC_100mME_wetDry.nc'
#grid = './test_grid_lonshift.nc'

#hc_grid_ds = xr.open_dataset('/import/c1/VERTMIX/jgpender/coawst/HC_100m_30layers/Experiments/HC_100m_2024.02.29/HC_100mME_wetDry.nc')
hc_ds = xr.open_mfdataset(netCDFs)
hc_grid_ds = xr.open_dataset(grid)

hc_native = reader_ROMS_native.Reader(f'{netCDFs}',gridfile=grid)

o2.add_reader(hc_native,)
# Out:
# 17:14:33 INFO    opendrift.readers.reader_ROMS_native:148: Opening dataset: /import/c1/VERTMIX/jgpender/coawst/HC_100m_30layers/Experiments/HC_100m_2024.03.01/netcdfOutput/hc_his_*.nc
# 17:14:33 INFO    opendrift.readers.reader_ROMS_native:150: Opening files with MFDataset
# 17:14:33 INFO    opendrift.readers.reader_ROMS_native:246: Read GLS parameters from file.
# 17:14:33 WARNING opendrift.readers.basereader.structured:50: No proj string or projection could be derived, using 'fakeproj'. This assumes that the variables are structured and gridded approximately equidistantly on the surface (i.e. in meters). This must be guaranteed by the user. You can get rid of this warning by supplying a valid projection to the reader.
# 17:14:33 INFO    opendrift.readers.basereader.structured:90: Making interpolator for lon,lat to x,y conversion...

# %%
# import numpy as np
# plt.pcolor(hc_native.Dataset['temp'][10,29,:,:])

# %%
# plt.pcolor(hc_native.Dataset.v[10,29,:,:])

# %%
# hc_native.center

# %%
hc_sill = (47.75,237.26)
#hc_sill = (47.75,-122.74)
dabob_mouth = (47.69555,237.141)


# o2.seed_elements(lon=hc_sill[1], 
#                 lat=hc_sill[0], 
#                 time=datetime(2024,3,2,0,0,),
#                 number=50, 
#                 radius=100)
o2.seed_elements(lon=dabob_mouth[1], 
                lat=dabob_mouth[0], 
                time=datetime(2024,3,1,0,0,),
                number=100, 
                radius=100,
                z=np.linspace(-95,-100,100)
                )
o2.plot()
# Out:
# 17:14:50 INFO    opendrift.models.basemodel.environment:220: Adding a dynamical landmask with max. priority based on assumed maximum speed of 1.0 m/s. Adding a customised landmask may be faster...
# 17:14:50 INFO    opendrift.models.basemodel.environment:247: Fallback values will be used for the following variables which have no readers:
# 17:14:50 INFO    opendrift.models.basemodel.environment:250: 	x_wind: 0.000000
# 17:14:50 INFO    opendrift.models.basemodel.environment:250: 	y_wind: 0.000000
# 17:14:50 INFO    opendrift.models.basemodel.environment:250: 	ocean_vertical_diffusivity: 0.000000
# 17:14:50 INFO    opendrift.models.basemodel.environment:250: 	sea_surface_wave_significant_height: 0.000000
# 17:14:50 INFO    opendrift.models.basemodel.environment:250: 	sea_surface_wave_stokes_drift_x_velocity: 0.000000
# 17:14:50 INFO    opendrift.models.basemodel.environment:250: 	sea_surface_wave_stokes_drift_y_velocity: 0.000000
# 17:14:50 INFO    opendrift.models.basemodel.environment:250: 	sea_surface_wave_period_at_variance_spectral_density_maximum: 0.000000
# 17:14:50 INFO    opendrift.models.basemodel.environment:250: 	sea_surface_wave_mean_period_from_variance_spectral_density_second_frequency_moment: 0.000000
# 17:14:50 INFO    opendrift.models.basemodel.environment:250: 	sea_surface_swell_wave_to_direction: 0.000000
# 17:14:50 INFO    opendrift.models.basemodel.environment:250: 	sea_surface_swell_wave_peak_period_from_variance_spectral_density: 0.000000
# 17:14:50 INFO    opendrift.models.basemodel.environment:250: 	sea_surface_swell_wave_significant_height: 0.000000
# 17:14:50 INFO    opendrift.models.basemodel.environment:250: 	sea_surface_wind_wave_to_direction: 0.000000
# 17:14:50 INFO    opendrift.models.basemodel.environment:250: 	sea_surface_wind_wave_mean_period: 0.000000
# 17:14:50 INFO    opendrift.models.basemodel.environment:250: 	sea_surface_wind_wave_significant_height: 0.000000
# 17:14:50 INFO    opendrift.models.basemodel.environment:250: 	surface_downward_x_stress: 0.000000
# 17:14:50 INFO    opendrift.models.basemodel.environment:250: 	surface_downward_y_stress: 0.000000
# 17:14:50 INFO    opendrift.models.basemodel.environment:250: 	ocean_mixed_layer_thickness: 50.000000
# (<GeoAxes: title={'center': 'OpenDrift - OceanDrift\n100 elements seeded at 2024-03-01 00:00 UTC'}>,
#  <Figure size 1100x819.039 with 1 Axes>)

# %%
o2.report_missing_variables
# Out:
# <bound method OpenDriftSimulation.report_missing_variables of ===========================
# Model:	OceanDrift     (OpenDrift version 1.11.1)
# 	0 active Lagrangian3DArray particles  (0 deactivated, 100 scheduled)
# -------------------
# Environment variables:
#   -----
#   sea_floor_depth_below_sea_level
#   turbulent_generic_length_scale
#   turbulent_kinetic_energy
#   upward_sea_water_velocity
#   x_sea_water_velocity
#   y_sea_water_velocity
#      1) roms native
#   -----
#   land_binary_mask
#      1) global_landmask
#   -----
# Readers not added for the following variables:
#   ocean_mixed_layer_thickness
#   ocean_vertical_diffusivity
#   sea_surface_swell_wave_peak_period_from_variance_spectral_density
#   sea_surface_swell_wave_significant_height
#   sea_surface_swell_wave_to_direction
#   sea_surface_wave_mean_period_from_variance_spectral_density_second_frequency_moment
#   sea_surface_wave_period_at_variance_spectral_density_maximum
#   sea_surface_wave_significant_height
#   sea_surface_wave_stokes_drift_x_velocity
#   sea_surface_wave_stokes_drift_y_velocity
#   sea_surface_wind_wave_mean_period
#   sea_surface_wind_wave_significant_height
#   sea_surface_wind_wave_to_direction
#   surface_downward_x_stress
#   surface_downward_y_stress
#   x_wind
#   y_wind
#
# Discarded readers:
# ===========================
# >

# %%
o2.run(time_step=timedelta(minutes=10),
      duration=timedelta(hours=48),
      outfile='test_output_95_100.nc');
#o2.plot()
# Out:
# 17:15:30 INFO    opendrift.models.basemodel:891: Using existing reader for land_binary_mask
# 17:15:30 INFO    opendrift.models.basemodel:903: All points are in ocean
# 17:15:30 INFO    opendrift.readers.reader_ROMS_native:318: Using mask_rho for mask_rho
# 17:15:30 INFO    opendrift.models.basemodel:1992: 2024-03-01 00:00:00 - step 1 of 288 - 100 active elements (0 deactivated)
# 17:15:30 INFO    opendrift.readers.reader_ROMS_native:339: Using mask_u for mask_u
# 17:15:31 INFO    opendrift.readers.reader_ROMS_native:535: Time: 0:00:01.139602
# 17:15:31 INFO    opendrift.readers.reader_ROMS_native:360: Using mask_v for mask_v
# 17:15:32 INFO    opendrift.models.basemodel:1992: 2024-03-01 00:10:00 - step 2 of 288 - 100 active elements (0 deactivated)
# 17:15:32 INFO    opendrift.models.basemodel:1992: 2024-03-01 00:20:00 - step 3 of 288 - 100 active elements (0 deactivated)
# 17:15:32 INFO    opendrift.models.basemodel:1992: 2024-03-01 00:30:00 - step 4 of 288 - 100 active elements (0 deactivated)
# 17:15:32 INFO    opendrift.models.basemodel:1992: 2024-03-01 00:40:00 - step 5 of 288 - 100 active elements (0 deactivated)
# 17:15:32 INFO    opendrift.models.basemodel:1992: 2024-03-01 00:50:00 - step 6 of 288 - 100 active elements (0 deactivated)
# 17:15:32 INFO    opendrift.models.basemodel:1992: 2024-03-01 01:00:00 - step 7 of 288 - 100 active elements (0 deactivated)
# 17:15:32 INFO    opendrift.models.basemodel:1992: 2024-03-01 01:10:00 - step 8 of 288 - 100 active elements (0 deactivated)
# 17:15:32 INFO    opendrift.models.basemodel:1992: 2024-03-01 01:20:00 - step 9 of 288 - 100 active elements (0 deactivated)
# 17:15:32 INFO    opendrift.models.basemodel:1992: 2024-03-01 01:30:00 - step 10 of 288 - 100 active elements (0 deactivated)
# 17:15:32 INFO    opendrift.models.basemodel:1992: 2024-03-01 01:40:00 - step 11 of 288 - 100 active elements (0 deactivated)
# 17:15:33 INFO    opendrift.models.basemodel:1992: 2024-03-01 01:50:00 - step 12 of 288 - 100 active elements (0 deactivated)
# 17:15:33 INFO    opendrift.models.basemodel:1992: 2024-03-01 02:00:00 - step 13 of 288 - 100 active elements (0 deactivated)
# 17:15:33 INFO    opendrift.models.basemodel:1992: 2024-03-01 02:10:00 - step 14 of 288 - 100 active elements (0 deactivated)
# 17:15:33 INFO    opendrift.models.basemodel:1992: 2024-03-01 02:20:00 - step 15 of 288 - 100 active elements (0 deactivated)
# 17:15:33 INFO    opendrift.models.basemodel:1992: 2024-03-01 02:30:00 - step 16 of 288 - 100 active elements (0 deactivated)
# 17:15:33 INFO    opendrift.models.basemodel:1992: 2024-03-01 02:40:00 - step 17 of 288 - 100 active elements (0 deactivated)
# 17:15:33 INFO    opendrift.models.basemodel:1992: 2024-03-01 02:50:00 - step 18 of 288 - 100 active elements (0 deactivated)
# 17:15:33 INFO    opendrift.models.basemodel:1992: 2024-03-01 03:00:00 - step 19 of 288 - 100 active elements (0 deactivated)
# 17:15:33 INFO    opendrift.models.basemodel:1992: 2024-03-01 03:10:00 - step 20 of 288 - 100 active elements (0 deactivated)
# 17:15:33 INFO    opendrift.models.basemodel:1992: 2024-03-01 03:20:00 - step 21 of 288 - 100 active elements (0 deactivated)
# 17:15:33 INFO    opendrift.models.basemodel:1992: 2024-03-01 03:30:00 - step 22 of 288 - 100 active elements (0 deactivated)
# 17:15:34 INFO    opendrift.models.basemodel:1992: 2024-03-01 03:40:00 - step 23 of 288 - 100 active elements (0 deactivated)
# 17:15:34 INFO    opendrift.models.basemodel:1992: 2024-03-01 03:50:00 - step 24 of 288 - 100 active elements (0 deactivated)
# 17:15:34 INFO    opendrift.models.basemodel:1992: 2024-03-01 04:00:00 - step 25 of 288 - 100 active elements (0 deactivated)
# 17:15:34 INFO    opendrift.models.basemodel:1992: 2024-03-01 04:10:00 - step 26 of 288 - 100 active elements (0 deactivated)
# 17:15:34 INFO    opendrift.models.basemodel:1992: 2024-03-01 04:20:00 - step 27 of 288 - 100 active elements (0 deactivated)
# 17:15:34 INFO    opendrift.models.basemodel:1992: 2024-03-01 04:30:00 - step 28 of 288 - 100 active elements (0 deactivated)
# 17:15:34 INFO    opendrift.models.basemodel:1992: 2024-03-01 04:40:00 - step 29 of 288 - 100 active elements (0 deactivated)
# 17:15:34 INFO    opendrift.models.basemodel:1992: 2024-03-01 04:50:00 - step 30 of 288 - 100 active elements (0 deactivated)
# 17:15:34 INFO    opendrift.models.basemodel:1992: 2024-03-01 05:00:00 - step 31 of 288 - 100 active elements (0 deactivated)
# 17:15:34 INFO    opendrift.models.basemodel:1992: 2024-03-01 05:10:00 - step 32 of 288 - 100 active elements (0 deactivated)
# 17:15:34 INFO    opendrift.models.basemodel:1992: 2024-03-01 05:20:00 - step 33 of 288 - 100 active elements (0 deactivated)
# 17:15:34 INFO    opendrift.models.basemodel:1992: 2024-03-01 05:30:00 - step 34 of 288 - 100 active elements (0 deactivated)
# 17:15:34 INFO    opendrift.models.basemodel:1992: 2024-03-01 05:40:00 - step 35 of 288 - 100 active elements (0 deactivated)
# 17:15:34 INFO    opendrift.models.basemodel:1992: 2024-03-01 05:50:00 - step 36 of 288 - 100 active elements (0 deactivated)
# 17:15:34 INFO    opendrift.models.basemodel:1992: 2024-03-01 06:00:00 - step 37 of 288 - 100 active elements (0 deactivated)
# 17:15:34 INFO    opendrift.models.basemodel:1992: 2024-03-01 06:10:00 - step 38 of 288 - 100 active elements (0 deactivated)
# 17:15:35 INFO    opendrift.models.basemodel:1992: 2024-03-01 06:20:00 - step 39 of 288 - 100 active elements (0 deactivated)
# 17:15:35 INFO    opendrift.models.basemodel:1992: 2024-03-01 06:30:00 - step 40 of 288 - 100 active elements (0 deactivated)
# 17:15:35 INFO    opendrift.models.basemodel:1992: 2024-03-01 06:40:00 - step 41 of 288 - 100 active elements (0 deactivated)
# 17:15:35 INFO    opendrift.models.basemodel:1992: 2024-03-01 06:50:00 - step 42 of 288 - 100 active elements (0 deactivated)
# 17:15:35 INFO    opendrift.models.basemodel:1992: 2024-03-01 07:00:00 - step 43 of 288 - 100 active elements (0 deactivated)
# 17:15:35 INFO    opendrift.models.basemodel:1992: 2024-03-01 07:10:00 - step 44 of 288 - 100 active elements (0 deactivated)
# 17:15:35 INFO    opendrift.models.basemodel:1992: 2024-03-01 07:20:00 - step 45 of 288 - 100 active elements (0 deactivated)
# 17:15:35 INFO    opendrift.models.basemodel:1992: 2024-03-01 07:30:00 - step 46 of 288 - 100 active elements (0 deactivated)
# 17:15:35 INFO    opendrift.models.basemodel:1992: 2024-03-01 07:40:00 - step 47 of 288 - 100 active elements (0 deactivated)
# 17:15:35 INFO    opendrift.models.basemodel:1992: 2024-03-01 07:50:00 - step 48 of 288 - 100 active elements (0 deactivated)
# 17:15:35 INFO    opendrift.models.basemodel:1992: 2024-03-01 08:00:00 - step 49 of 288 - 100 active elements (0 deactivated)
# 17:15:35 INFO    opendrift.models.basemodel:1992: 2024-03-01 08:10:00 - step 50 of 288 - 100 active elements (0 deactivated)
# 17:15:35 INFO    opendrift.models.basemodel:1992: 2024-03-01 08:20:00 - step 51 of 288 - 100 active elements (0 deactivated)
# 17:15:35 INFO    opendrift.models.basemodel:1992: 2024-03-01 08:30:00 - step 52 of 288 - 100 active elements (0 deactivated)
# 17:15:35 INFO    opendrift.models.basemodel:1992: 2024-03-01 08:40:00 - step 53 of 288 - 100 active elements (0 deactivated)
# 17:15:35 INFO    opendrift.models.basemodel:1992: 2024-03-01 08:50:00 - step 54 of 288 - 100 active elements (0 deactivated)
# 17:15:35 INFO    opendrift.models.basemodel:1992: 2024-03-01 09:00:00 - step 55 of 288 - 100 active elements (0 deactivated)
# 17:15:35 INFO    opendrift.models.basemodel:1992: 2024-03-01 09:10:00 - step 56 of 288 - 100 active elements (0 deactivated)
# 17:15:36 INFO    opendrift.models.basemodel:1992: 2024-03-01 09:20:00 - step 57 of 288 - 100 active elements (0 deactivated)
# 17:15:36 INFO    opendrift.models.basemodel:1992: 2024-03-01 09:30:00 - step 58 of 288 - 100 active elements (0 deactivated)
# 17:15:36 INFO    opendrift.models.basemodel:1992: 2024-03-01 09:40:00 - step 59 of 288 - 100 active elements (0 deactivated)
# 17:15:36 INFO    opendrift.models.basemodel:1992: 2024-03-01 09:50:00 - step 60 of 288 - 100 active elements (0 deactivated)
# 17:15:36 INFO    opendrift.models.basemodel:1992: 2024-03-01 10:00:00 - step 61 of 288 - 100 active elements (0 deactivated)
# 17:15:36 INFO    opendrift.models.basemodel:1992: 2024-03-01 10:10:00 - step 62 of 288 - 100 active elements (0 deactivated)
# 17:15:36 INFO    opendrift.models.basemodel:1992: 2024-03-01 10:20:00 - step 63 of 288 - 100 active elements (0 deactivated)
# 17:15:36 INFO    opendrift.models.basemodel:1992: 2024-03-01 10:30:00 - step 64 of 288 - 100 active elements (0 deactivated)
# 17:15:36 INFO    opendrift.models.basemodel:1992: 2024-03-01 10:40:00 - step 65 of 288 - 100 active elements (0 deactivated)
# 17:15:36 INFO    opendrift.models.basemodel:1992: 2024-03-01 10:50:00 - step 66 of 288 - 100 active elements (0 deactivated)
# 17:15:36 INFO    opendrift.models.basemodel:1992: 2024-03-01 11:00:00 - step 67 of 288 - 100 active elements (0 deactivated)
# 17:15:36 INFO    opendrift.models.basemodel:1992: 2024-03-01 11:10:00 - step 68 of 288 - 100 active elements (0 deactivated)
# 17:15:36 INFO    opendrift.models.basemodel:1992: 2024-03-01 11:20:00 - step 69 of 288 - 100 active elements (0 deactivated)
# 17:15:36 INFO    opendrift.models.basemodel:1992: 2024-03-01 11:30:00 - step 70 of 288 - 100 active elements (0 deactivated)
# 17:15:36 INFO    opendrift.models.basemodel:1992: 2024-03-01 11:40:00 - step 71 of 288 - 100 active elements (0 deactivated)
# 17:15:36 INFO    opendrift.models.basemodel:1992: 2024-03-01 11:50:00 - step 72 of 288 - 100 active elements (0 deactivated)
# 17:15:36 INFO    opendrift.models.basemodel:1992: 2024-03-01 12:00:00 - step 73 of 288 - 100 active elements (0 deactivated)
# 17:15:36 INFO    opendrift.models.basemodel:1992: 2024-03-01 12:10:00 - step 74 of 288 - 100 active elements (0 deactivated)
# 17:15:37 INFO    opendrift.models.basemodel:1992: 2024-03-01 12:20:00 - step 75 of 288 - 100 active elements (0 deactivated)
# 17:15:37 INFO    opendrift.models.basemodel:1992: 2024-03-01 12:30:00 - step 76 of 288 - 100 active elements (0 deactivated)
# 17:15:37 INFO    opendrift.models.basemodel:1992: 2024-03-01 12:40:00 - step 77 of 288 - 100 active elements (0 deactivated)
# 17:15:37 INFO    opendrift.models.basemodel:1992: 2024-03-01 12:50:00 - step 78 of 288 - 100 active elements (0 deactivated)
# 17:15:37 INFO    opendrift.models.basemodel:1992: 2024-03-01 13:00:00 - step 79 of 288 - 100 active elements (0 deactivated)
# 17:15:37 INFO    opendrift.models.basemodel:1992: 2024-03-01 13:10:00 - step 80 of 288 - 100 active elements (0 deactivated)
# 17:15:37 INFO    opendrift.models.basemodel:1992: 2024-03-01 13:20:00 - step 81 of 288 - 100 active elements (0 deactivated)
# 17:15:37 INFO    opendrift.models.basemodel:1992: 2024-03-01 13:30:00 - step 82 of 288 - 100 active elements (0 deactivated)
# 17:15:37 INFO    opendrift.models.basemodel:1992: 2024-03-01 13:40:00 - step 83 of 288 - 100 active elements (0 deactivated)
# 17:15:37 INFO    opendrift.models.basemodel:1992: 2024-03-01 13:50:00 - step 84 of 288 - 100 active elements (0 deactivated)
# 17:15:37 INFO    opendrift.models.basemodel:1992: 2024-03-01 14:00:00 - step 85 of 288 - 100 active elements (0 deactivated)
# 17:15:37 INFO    opendrift.models.basemodel:1992: 2024-03-01 14:10:00 - step 86 of 288 - 100 active elements (0 deactivated)
# 17:15:37 INFO    opendrift.models.basemodel:1992: 2024-03-01 14:20:00 - step 87 of 288 - 100 active elements (0 deactivated)
# 17:15:37 INFO    opendrift.models.basemodel:1992: 2024-03-01 14:30:00 - step 88 of 288 - 100 active elements (0 deactivated)
# 17:15:37 INFO    opendrift.models.basemodel:1992: 2024-03-01 14:40:00 - step 89 of 288 - 100 active elements (0 deactivated)
# 17:15:37 INFO    opendrift.models.basemodel:1992: 2024-03-01 14:50:00 - step 90 of 288 - 100 active elements (0 deactivated)
# 17:15:37 INFO    opendrift.models.basemodel:1992: 2024-03-01 15:00:00 - step 91 of 288 - 100 active elements (0 deactivated)
# 17:15:37 INFO    opendrift.models.basemodel:1992: 2024-03-01 15:10:00 - step 92 of 288 - 100 active elements (0 deactivated)
# 17:15:38 INFO    opendrift.models.basemodel:1992: 2024-03-01 15:20:00 - step 93 of 288 - 100 active elements (0 deactivated)
# 17:15:38 INFO    opendrift.models.basemodel:1992: 2024-03-01 15:30:00 - step 94 of 288 - 100 active elements (0 deactivated)
# 17:15:38 INFO    opendrift.models.basemodel:1992: 2024-03-01 15:40:00 - step 95 of 288 - 100 active elements (0 deactivated)
# 17:15:38 INFO    opendrift.models.basemodel:1992: 2024-03-01 15:50:00 - step 96 of 288 - 100 active elements (0 deactivated)
# 17:15:38 INFO    opendrift.models.basemodel:1992: 2024-03-01 16:00:00 - step 97 of 288 - 100 active elements (0 deactivated)
# 17:15:38 INFO    opendrift.models.basemodel:1992: 2024-03-01 16:10:00 - step 98 of 288 - 100 active elements (0 deactivated)
# 17:15:38 INFO    opendrift.models.basemodel:1992: 2024-03-01 16:20:00 - step 99 of 288 - 100 active elements (0 deactivated)
# 17:15:38 INFO    opendrift.models.basemodel:1992: 2024-03-01 16:30:00 - step 100 of 288 - 100 active elements (0 deactivated)
# 17:15:38 INFO    opendrift.export.io_netcdf:112: Wrote 100 steps to file test_output_95_100.nc
# 17:15:38 INFO    opendrift.models.basemodel:1992: 2024-03-01 16:40:00 - step 101 of 288 - 100 active elements (0 deactivated)
# 17:15:38 INFO    opendrift.models.basemodel:1992: 2024-03-01 16:50:00 - step 102 of 288 - 100 active elements (0 deactivated)
# 17:15:38 INFO    opendrift.models.basemodel:1992: 2024-03-01 17:00:00 - step 103 of 288 - 100 active elements (0 deactivated)
# 17:15:38 INFO    opendrift.models.basemodel:1992: 2024-03-01 17:10:00 - step 104 of 288 - 100 active elements (0 deactivated)
# 17:15:38 INFO    opendrift.models.basemodel:1992: 2024-03-01 17:20:00 - step 105 of 288 - 100 active elements (0 deactivated)
# 17:15:38 INFO    opendrift.models.basemodel:1992: 2024-03-01 17:30:00 - step 106 of 288 - 100 active elements (0 deactivated)
# 17:15:38 INFO    opendrift.models.basemodel:1992: 2024-03-01 17:40:00 - step 107 of 288 - 100 active elements (0 deactivated)
# 17:15:38 INFO    opendrift.models.basemodel:1992: 2024-03-01 17:50:00 - step 108 of 288 - 100 active elements (0 deactivated)
# 17:15:38 INFO    opendrift.models.basemodel:1992: 2024-03-01 18:00:00 - step 109 of 288 - 100 active elements (0 deactivated)
# 17:15:38 INFO    opendrift.models.basemodel:1992: 2024-03-01 18:10:00 - step 110 of 288 - 100 active elements (0 deactivated)
# 17:15:39 INFO    opendrift.models.basemodel:1992: 2024-03-01 18:20:00 - step 111 of 288 - 100 active elements (0 deactivated)
# 17:15:39 INFO    opendrift.models.basemodel:1992: 2024-03-01 18:30:00 - step 112 of 288 - 100 active elements (0 deactivated)
# 17:15:39 INFO    opendrift.models.basemodel:1992: 2024-03-01 18:40:00 - step 113 of 288 - 100 active elements (0 deactivated)
# 17:15:39 INFO    opendrift.models.basemodel:1992: 2024-03-01 18:50:00 - step 114 of 288 - 100 active elements (0 deactivated)
# 17:15:39 INFO    opendrift.models.basemodel:1992: 2024-03-01 19:00:00 - step 115 of 288 - 100 active elements (0 deactivated)
# 17:15:39 INFO    opendrift.models.basemodel:1992: 2024-03-01 19:10:00 - step 116 of 288 - 100 active elements (0 deactivated)
# 17:15:39 INFO    opendrift.models.basemodel:1992: 2024-03-01 19:20:00 - step 117 of 288 - 100 active elements (0 deactivated)
# 17:15:39 INFO    opendrift.models.basemodel:1992: 2024-03-01 19:30:00 - step 118 of 288 - 100 active elements (0 deactivated)
# 17:15:39 INFO    opendrift.models.basemodel:1992: 2024-03-01 19:40:00 - step 119 of 288 - 100 active elements (0 deactivated)
# 17:15:39 INFO    opendrift.models.basemodel:1992: 2024-03-01 19:50:00 - step 120 of 288 - 100 active elements (0 deactivated)
# 17:15:39 INFO    opendrift.models.basemodel:1992: 2024-03-01 20:00:00 - step 121 of 288 - 100 active elements (0 deactivated)
# 17:15:39 INFO    opendrift.models.basemodel:1992: 2024-03-01 20:10:00 - step 122 of 288 - 100 active elements (0 deactivated)
# 17:15:39 INFO    opendrift.models.basemodel:1992: 2024-03-01 20:20:00 - step 123 of 288 - 100 active elements (0 deactivated)
# 17:15:39 INFO    opendrift.models.basemodel:1992: 2024-03-01 20:30:00 - step 124 of 288 - 100 active elements (0 deactivated)
# 17:15:39 INFO    opendrift.models.basemodel:1992: 2024-03-01 20:40:00 - step 125 of 288 - 100 active elements (0 deactivated)
# 17:15:40 INFO    opendrift.models.basemodel:1992: 2024-03-01 20:50:00 - step 126 of 288 - 100 active elements (0 deactivated)
# 17:15:40 INFO    opendrift.models.basemodel:1992: 2024-03-01 21:00:00 - step 127 of 288 - 100 active elements (0 deactivated)
# 17:15:40 INFO    opendrift.models.basemodel:1992: 2024-03-01 21:10:00 - step 128 of 288 - 100 active elements (0 deactivated)
# 17:15:40 INFO    opendrift.models.basemodel:1992: 2024-03-01 21:20:00 - step 129 of 288 - 100 active elements (0 deactivated)
# 17:15:40 INFO    opendrift.models.basemodel:1992: 2024-03-01 21:30:00 - step 130 of 288 - 100 active elements (0 deactivated)
# 17:15:40 INFO    opendrift.models.basemodel:1992: 2024-03-01 21:40:00 - step 131 of 288 - 100 active elements (0 deactivated)
# 17:15:40 INFO    opendrift.models.basemodel:1992: 2024-03-01 21:50:00 - step 132 of 288 - 100 active elements (0 deactivated)
# 17:15:40 INFO    opendrift.models.basemodel:1992: 2024-03-01 22:00:00 - step 133 of 288 - 100 active elements (0 deactivated)
# 17:15:40 INFO    opendrift.models.basemodel:1992: 2024-03-01 22:10:00 - step 134 of 288 - 100 active elements (0 deactivated)
# 17:15:40 INFO    opendrift.models.basemodel:1992: 2024-03-01 22:20:00 - step 135 of 288 - 100 active elements (0 deactivated)
# 17:15:40 INFO    opendrift.models.basemodel:1992: 2024-03-01 22:30:00 - step 136 of 288 - 100 active elements (0 deactivated)
# 17:15:40 INFO    opendrift.models.basemodel:1992: 2024-03-01 22:40:00 - step 137 of 288 - 100 active elements (0 deactivated)
# 17:15:40 INFO    opendrift.models.basemodel:1992: 2024-03-01 22:50:00 - step 138 of 288 - 100 active elements (0 deactivated)
# 17:15:41 INFO    opendrift.models.basemodel:1992: 2024-03-01 23:00:00 - step 139 of 288 - 100 active elements (0 deactivated)
# 17:15:41 INFO    opendrift.models.basemodel:1992: 2024-03-01 23:10:00 - step 140 of 288 - 100 active elements (0 deactivated)
# 17:15:41 INFO    opendrift.models.basemodel:1992: 2024-03-01 23:20:00 - step 141 of 288 - 100 active elements (0 deactivated)
# 17:15:41 INFO    opendrift.models.basemodel:1992: 2024-03-01 23:30:00 - step 142 of 288 - 100 active elements (0 deactivated)
# 17:15:41 INFO    opendrift.models.basemodel:1992: 2024-03-01 23:40:00 - step 143 of 288 - 100 active elements (0 deactivated)
# 17:15:41 INFO    opendrift.models.basemodel:1992: 2024-03-01 23:50:00 - step 144 of 288 - 100 active elements (0 deactivated)
# 17:15:41 INFO    opendrift.models.basemodel:1992: 2024-03-02 00:00:00 - step 145 of 288 - 100 active elements (0 deactivated)
# 17:15:41 INFO    opendrift.models.basemodel:1992: 2024-03-02 00:10:00 - step 146 of 288 - 100 active elements (0 deactivated)
# 17:15:41 INFO    opendrift.models.basemodel:1992: 2024-03-02 00:20:00 - step 147 of 288 - 100 active elements (0 deactivated)
# 17:15:41 INFO    opendrift.models.basemodel:1992: 2024-03-02 00:30:00 - step 148 of 288 - 100 active elements (0 deactivated)
# 17:15:41 INFO    opendrift.models.basemodel:1992: 2024-03-02 00:40:00 - step 149 of 288 - 100 active elements (0 deactivated)
# 17:15:42 INFO    opendrift.models.basemodel:1992: 2024-03-02 00:50:00 - step 150 of 288 - 100 active elements (0 deactivated)
# 17:15:42 INFO    opendrift.models.basemodel:1992: 2024-03-02 01:00:00 - step 151 of 288 - 100 active elements (0 deactivated)
# 17:15:42 INFO    opendrift.models.basemodel:1992: 2024-03-02 01:10:00 - step 152 of 288 - 100 active elements (0 deactivated)
# 17:15:42 INFO    opendrift.models.basemodel:1992: 2024-03-02 01:20:00 - step 153 of 288 - 100 active elements (0 deactivated)
# 17:15:42 INFO    opendrift.models.basemodel:1992: 2024-03-02 01:30:00 - step 154 of 288 - 100 active elements (0 deactivated)
# 17:15:42 INFO    opendrift.models.basemodel:1992: 2024-03-02 01:40:00 - step 155 of 288 - 100 active elements (0 deactivated)
# 17:15:42 INFO    opendrift.models.basemodel:1992: 2024-03-02 01:50:00 - step 156 of 288 - 100 active elements (0 deactivated)
# 17:15:42 INFO    opendrift.models.basemodel:1992: 2024-03-02 02:00:00 - step 157 of 288 - 100 active elements (0 deactivated)
# 17:15:42 INFO    opendrift.models.basemodel:1992: 2024-03-02 02:10:00 - step 158 of 288 - 100 active elements (0 deactivated)
# 17:15:42 INFO    opendrift.models.basemodel:1992: 2024-03-02 02:20:00 - step 159 of 288 - 100 active elements (0 deactivated)
# 17:15:42 INFO    opendrift.models.basemodel:1992: 2024-03-02 02:30:00 - step 160 of 288 - 100 active elements (0 deactivated)
# 17:15:42 INFO    opendrift.models.basemodel:1992: 2024-03-02 02:40:00 - step 161 of 288 - 100 active elements (0 deactivated)
# 17:15:42 INFO    opendrift.models.basemodel:1992: 2024-03-02 02:50:00 - step 162 of 288 - 100 active elements (0 deactivated)
# 17:15:42 INFO    opendrift.models.basemodel:1992: 2024-03-02 03:00:00 - step 163 of 288 - 100 active elements (0 deactivated)
# 17:15:42 INFO    opendrift.models.basemodel:1992: 2024-03-02 03:10:00 - step 164 of 288 - 100 active elements (0 deactivated)
# 17:15:43 INFO    opendrift.models.basemodel:1992: 2024-03-02 03:20:00 - step 165 of 288 - 100 active elements (0 deactivated)
# 17:15:43 INFO    opendrift.models.basemodel:1992: 2024-03-02 03:30:00 - step 166 of 288 - 100 active elements (0 deactivated)
# 17:15:43 INFO    opendrift.models.basemodel:1992: 2024-03-02 03:40:00 - step 167 of 288 - 100 active elements (0 deactivated)
# 17:15:43 INFO    opendrift.models.basemodel:1992: 2024-03-02 03:50:00 - step 168 of 288 - 100 active elements (0 deactivated)
# 17:15:43 INFO    opendrift.models.basemodel:1992: 2024-03-02 04:00:00 - step 169 of 288 - 100 active elements (0 deactivated)
# 17:15:43 INFO    opendrift.models.basemodel:1992: 2024-03-02 04:10:00 - step 170 of 288 - 100 active elements (0 deactivated)
# 17:15:43 INFO    opendrift.models.basemodel:1992: 2024-03-02 04:20:00 - step 171 of 288 - 100 active elements (0 deactivated)
# 17:15:43 INFO    opendrift.models.basemodel:1992: 2024-03-02 04:30:00 - step 172 of 288 - 100 active elements (0 deactivated)
# 17:15:43 INFO    opendrift.models.basemodel:1992: 2024-03-02 04:40:00 - step 173 of 288 - 100 active elements (0 deactivated)
# 17:15:43 INFO    opendrift.models.basemodel:1992: 2024-03-02 04:50:00 - step 174 of 288 - 100 active elements (0 deactivated)
# 17:15:43 INFO    opendrift.models.basemodel:1992: 2024-03-02 05:00:00 - step 175 of 288 - 100 active elements (0 deactivated)
# 17:15:43 INFO    opendrift.models.basemodel:1992: 2024-03-02 05:10:00 - step 176 of 288 - 100 active elements (0 deactivated)
# 17:15:43 INFO    opendrift.models.basemodel:1992: 2024-03-02 05:20:00 - step 177 of 288 - 100 active elements (0 deactivated)
# 17:15:43 INFO    opendrift.models.basemodel:1992: 2024-03-02 05:30:00 - step 178 of 288 - 100 active elements (0 deactivated)
# 17:15:43 INFO    opendrift.models.basemodel:1992: 2024-03-02 05:40:00 - step 179 of 288 - 100 active elements (0 deactivated)
# 17:15:43 INFO    opendrift.models.basemodel:1992: 2024-03-02 05:50:00 - step 180 of 288 - 100 active elements (0 deactivated)
# 17:15:43 INFO    opendrift.models.basemodel:1992: 2024-03-02 06:00:00 - step 181 of 288 - 100 active elements (0 deactivated)
# 17:15:43 INFO    opendrift.models.basemodel:1992: 2024-03-02 06:10:00 - step 182 of 288 - 100 active elements (0 deactivated)
# 17:15:44 INFO    opendrift.models.basemodel:1992: 2024-03-02 06:20:00 - step 183 of 288 - 100 active elements (0 deactivated)
# 17:15:44 INFO    opendrift.models.basemodel:1992: 2024-03-02 06:30:00 - step 184 of 288 - 100 active elements (0 deactivated)
# 17:15:44 INFO    opendrift.models.basemodel:1992: 2024-03-02 06:40:00 - step 185 of 288 - 100 active elements (0 deactivated)
# 17:15:44 INFO    opendrift.models.basemodel:1992: 2024-03-02 06:50:00 - step 186 of 288 - 100 active elements (0 deactivated)
# 17:15:44 INFO    opendrift.models.basemodel:1992: 2024-03-02 07:00:00 - step 187 of 288 - 100 active elements (0 deactivated)
# 17:15:44 INFO    opendrift.models.basemodel:1992: 2024-03-02 07:10:00 - step 188 of 288 - 100 active elements (0 deactivated)
# 17:15:44 INFO    opendrift.models.basemodel:1992: 2024-03-02 07:20:00 - step 189 of 288 - 100 active elements (0 deactivated)
# 17:15:44 INFO    opendrift.models.basemodel:1992: 2024-03-02 07:30:00 - step 190 of 288 - 100 active elements (0 deactivated)
# 17:15:44 INFO    opendrift.models.basemodel:1992: 2024-03-02 07:40:00 - step 191 of 288 - 100 active elements (0 deactivated)
# 17:15:44 INFO    opendrift.models.basemodel:1992: 2024-03-02 07:50:00 - step 192 of 288 - 100 active elements (0 deactivated)
# 17:15:44 INFO    opendrift.models.basemodel:1992: 2024-03-02 08:00:00 - step 193 of 288 - 100 active elements (0 deactivated)
# 17:15:44 INFO    opendrift.models.basemodel:1992: 2024-03-02 08:10:00 - step 194 of 288 - 100 active elements (0 deactivated)
# 17:15:44 INFO    opendrift.models.basemodel:1992: 2024-03-02 08:20:00 - step 195 of 288 - 100 active elements (0 deactivated)
# 17:15:44 INFO    opendrift.models.basemodel:1992: 2024-03-02 08:30:00 - step 196 of 288 - 100 active elements (0 deactivated)
# 17:15:44 INFO    opendrift.models.basemodel:1992: 2024-03-02 08:40:00 - step 197 of 288 - 100 active elements (0 deactivated)
# 17:15:44 INFO    opendrift.models.basemodel:1992: 2024-03-02 08:50:00 - step 198 of 288 - 100 active elements (0 deactivated)
# 17:15:44 INFO    opendrift.models.basemodel:1992: 2024-03-02 09:00:00 - step 199 of 288 - 100 active elements (0 deactivated)
# 17:15:44 INFO    opendrift.models.basemodel:1992: 2024-03-02 09:10:00 - step 200 of 288 - 100 active elements (0 deactivated)
# 17:15:45 INFO    opendrift.export.io_netcdf:112: Wrote 100 steps to file test_output_95_100.nc
# 17:15:45 INFO    opendrift.models.basemodel:1992: 2024-03-02 09:20:00 - step 201 of 288 - 100 active elements (0 deactivated)
# 17:15:45 INFO    opendrift.models.basemodel:1992: 2024-03-02 09:30:00 - step 202 of 288 - 100 active elements (0 deactivated)
# 17:15:45 INFO    opendrift.models.basemodel:1992: 2024-03-02 09:40:00 - step 203 of 288 - 100 active elements (0 deactivated)
# 17:15:45 INFO    opendrift.models.basemodel:1992: 2024-03-02 09:50:00 - step 204 of 288 - 100 active elements (0 deactivated)
# 17:15:45 INFO    opendrift.models.basemodel:1992: 2024-03-02 10:00:00 - step 205 of 288 - 100 active elements (0 deactivated)
# 17:15:45 INFO    opendrift.models.basemodel:1992: 2024-03-02 10:10:00 - step 206 of 288 - 100 active elements (0 deactivated)
# 17:15:45 INFO    opendrift.models.basemodel:1992: 2024-03-02 10:20:00 - step 207 of 288 - 100 active elements (0 deactivated)
# 17:15:45 INFO    opendrift.models.basemodel:1992: 2024-03-02 10:30:00 - step 208 of 288 - 100 active elements (0 deactivated)
# 17:15:45 INFO    opendrift.models.basemodel:1992: 2024-03-02 10:40:00 - step 209 of 288 - 100 active elements (0 deactivated)
# 17:15:45 INFO    opendrift.models.basemodel:1992: 2024-03-02 10:50:00 - step 210 of 288 - 100 active elements (0 deactivated)
# 17:15:45 INFO    opendrift.models.basemodel:1992: 2024-03-02 11:00:00 - step 211 of 288 - 100 active elements (0 deactivated)
# 17:15:45 INFO    opendrift.models.basemodel:1992: 2024-03-02 11:10:00 - step 212 of 288 - 100 active elements (0 deactivated)
# 17:15:45 INFO    opendrift.models.basemodel:1992: 2024-03-02 11:20:00 - step 213 of 288 - 100 active elements (0 deactivated)
# 17:15:45 INFO    opendrift.models.basemodel:1992: 2024-03-02 11:30:00 - step 214 of 288 - 100 active elements (0 deactivated)
# 17:15:45 INFO    opendrift.models.basemodel:1992: 2024-03-02 11:40:00 - step 215 of 288 - 100 active elements (0 deactivated)
# 17:15:45 INFO    opendrift.models.basemodel:1992: 2024-03-02 11:50:00 - step 216 of 288 - 100 active elements (0 deactivated)
# 17:15:45 INFO    opendrift.models.basemodel:1992: 2024-03-02 12:00:00 - step 217 of 288 - 100 active elements (0 deactivated)
# 17:15:45 INFO    opendrift.models.basemodel:1992: 2024-03-02 12:10:00 - step 218 of 288 - 100 active elements (0 deactivated)
# 17:15:46 INFO    opendrift.models.basemodel:1992: 2024-03-02 12:20:00 - step 219 of 288 - 100 active elements (0 deactivated)
# 17:15:46 INFO    opendrift.models.basemodel:1992: 2024-03-02 12:30:00 - step 220 of 288 - 100 active elements (0 deactivated)
# 17:15:46 INFO    opendrift.models.basemodel:1992: 2024-03-02 12:40:00 - step 221 of 288 - 100 active elements (0 deactivated)
# 17:15:46 INFO    opendrift.models.basemodel:1992: 2024-03-02 12:50:00 - step 222 of 288 - 100 active elements (0 deactivated)
# 17:15:46 INFO    opendrift.models.basemodel:1992: 2024-03-02 13:00:00 - step 223 of 288 - 100 active elements (0 deactivated)
# 17:15:46 INFO    opendrift.models.basemodel:1992: 2024-03-02 13:10:00 - step 224 of 288 - 100 active elements (0 deactivated)
# 17:15:46 INFO    opendrift.models.basemodel:1992: 2024-03-02 13:20:00 - step 225 of 288 - 100 active elements (0 deactivated)
# 17:15:46 INFO    opendrift.models.basemodel:1992: 2024-03-02 13:30:00 - step 226 of 288 - 100 active elements (0 deactivated)
# 17:15:46 INFO    opendrift.models.basemodel:1992: 2024-03-02 13:40:00 - step 227 of 288 - 100 active elements (0 deactivated)
# 17:15:46 INFO    opendrift.models.basemodel:1992: 2024-03-02 13:50:00 - step 228 of 288 - 100 active elements (0 deactivated)
# 17:15:46 INFO    opendrift.models.basemodel:1992: 2024-03-02 14:00:00 - step 229 of 288 - 100 active elements (0 deactivated)
# 17:15:46 INFO    opendrift.models.basemodel:1992: 2024-03-02 14:10:00 - step 230 of 288 - 100 active elements (0 deactivated)
# 17:15:46 INFO    opendrift.models.basemodel:1992: 2024-03-02 14:20:00 - step 231 of 288 - 100 active elements (0 deactivated)
# 17:15:46 INFO    opendrift.models.basemodel:1992: 2024-03-02 14:30:00 - step 232 of 288 - 100 active elements (0 deactivated)
# 17:15:46 INFO    opendrift.models.basemodel:1992: 2024-03-02 14:40:00 - step 233 of 288 - 100 active elements (0 deactivated)
# 17:15:46 INFO    opendrift.models.basemodel:1992: 2024-03-02 14:50:00 - step 234 of 288 - 100 active elements (0 deactivated)
# 17:15:47 INFO    opendrift.models.basemodel:1992: 2024-03-02 15:00:00 - step 235 of 288 - 100 active elements (0 deactivated)
# 17:15:47 INFO    opendrift.models.basemodel:1992: 2024-03-02 15:10:00 - step 236 of 288 - 100 active elements (0 deactivated)
# 17:15:47 INFO    opendrift.models.basemodel:1992: 2024-03-02 15:20:00 - step 237 of 288 - 100 active elements (0 deactivated)
# 17:15:47 INFO    opendrift.models.basemodel:1992: 2024-03-02 15:30:00 - step 238 of 288 - 100 active elements (0 deactivated)
# 17:15:47 INFO    opendrift.models.basemodel:1992: 2024-03-02 15:40:00 - step 239 of 288 - 100 active elements (0 deactivated)
# 17:15:47 INFO    opendrift.models.basemodel:1992: 2024-03-02 15:50:00 - step 240 of 288 - 100 active elements (0 deactivated)
# 17:15:47 INFO    opendrift.models.basemodel:1992: 2024-03-02 16:00:00 - step 241 of 288 - 100 active elements (0 deactivated)
# 17:15:47 INFO    opendrift.models.basemodel:1992: 2024-03-02 16:10:00 - step 242 of 288 - 100 active elements (0 deactivated)
# 17:15:47 INFO    opendrift.models.basemodel:1992: 2024-03-02 16:20:00 - step 243 of 288 - 100 active elements (0 deactivated)
# 17:15:47 INFO    opendrift.models.basemodel:1992: 2024-03-02 16:30:00 - step 244 of 288 - 100 active elements (0 deactivated)
# 17:15:47 INFO    opendrift.models.basemodel:1992: 2024-03-02 16:40:00 - step 245 of 288 - 100 active elements (0 deactivated)
# 17:15:47 INFO    opendrift.models.basemodel:1992: 2024-03-02 16:50:00 - step 246 of 288 - 100 active elements (0 deactivated)
# 17:15:48 INFO    opendrift.models.basemodel:1992: 2024-03-02 17:00:00 - step 247 of 288 - 100 active elements (0 deactivated)
# 17:15:48 INFO    opendrift.models.basemodel:1992: 2024-03-02 17:10:00 - step 248 of 288 - 100 active elements (0 deactivated)
# 17:15:48 INFO    opendrift.models.basemodel:1992: 2024-03-02 17:20:00 - step 249 of 288 - 100 active elements (0 deactivated)
# 17:15:48 INFO    opendrift.models.basemodel:1992: 2024-03-02 17:30:00 - step 250 of 288 - 100 active elements (0 deactivated)
# 17:15:48 INFO    opendrift.models.basemodel:1992: 2024-03-02 17:40:00 - step 251 of 288 - 100 active elements (0 deactivated)
# 17:15:48 INFO    opendrift.models.basemodel:1992: 2024-03-02 17:50:00 - step 252 of 288 - 100 active elements (0 deactivated)
# 17:15:48 INFO    opendrift.models.basemodel:1992: 2024-03-02 18:00:00 - step 253 of 288 - 100 active elements (0 deactivated)
# 17:15:48 INFO    opendrift.models.basemodel:1992: 2024-03-02 18:10:00 - step 254 of 288 - 100 active elements (0 deactivated)
# 17:15:48 INFO    opendrift.models.basemodel:1992: 2024-03-02 18:20:00 - step 255 of 288 - 100 active elements (0 deactivated)
# 17:15:48 INFO    opendrift.models.basemodel:1992: 2024-03-02 18:30:00 - step 256 of 288 - 100 active elements (0 deactivated)
# 17:15:48 INFO    opendrift.models.basemodel:1992: 2024-03-02 18:40:00 - step 257 of 288 - 100 active elements (0 deactivated)
# 17:15:48 INFO    opendrift.models.basemodel:1992: 2024-03-02 18:50:00 - step 258 of 288 - 99 active elements (1 deactivated)
# 17:15:49 INFO    opendrift.models.basemodel:1992: 2024-03-02 19:00:00 - step 259 of 288 - 99 active elements (1 deactivated)
# 17:15:49 INFO    opendrift.models.basemodel:1992: 2024-03-02 19:10:00 - step 260 of 288 - 99 active elements (1 deactivated)
# 17:15:49 INFO    opendrift.models.basemodel:1992: 2024-03-02 19:20:00 - step 261 of 288 - 98 active elements (2 deactivated)
# 17:15:49 INFO    opendrift.models.basemodel:1992: 2024-03-02 19:30:00 - step 262 of 288 - 98 active elements (2 deactivated)
# 17:15:49 INFO    opendrift.models.basemodel:1992: 2024-03-02 19:40:00 - step 263 of 288 - 98 active elements (2 deactivated)
# 17:15:49 INFO    opendrift.models.basemodel:1992: 2024-03-02 19:50:00 - step 264 of 288 - 98 active elements (2 deactivated)
# 17:15:49 INFO    opendrift.models.basemodel:1992: 2024-03-02 20:00:00 - step 265 of 288 - 98 active elements (2 deactivated)
# 17:15:49 INFO    opendrift.models.basemodel:1992: 2024-03-02 20:10:00 - step 266 of 288 - 98 active elements (2 deactivated)
# 17:15:49 INFO    opendrift.models.basemodel:1992: 2024-03-02 20:20:00 - step 267 of 288 - 98 active elements (2 deactivated)
# 17:15:49 INFO    opendrift.models.basemodel:1992: 2024-03-02 20:30:00 - step 268 of 288 - 98 active elements (2 deactivated)
# 17:15:49 INFO    opendrift.models.basemodel:1992: 2024-03-02 20:40:00 - step 269 of 288 - 98 active elements (2 deactivated)
# 17:15:49 INFO    opendrift.models.basemodel:1992: 2024-03-02 20:50:00 - step 270 of 288 - 98 active elements (2 deactivated)
# 17:15:49 INFO    opendrift.models.basemodel:1992: 2024-03-02 21:00:00 - step 271 of 288 - 98 active elements (2 deactivated)
# 17:15:49 INFO    opendrift.models.basemodel:1992: 2024-03-02 21:10:00 - step 272 of 288 - 98 active elements (2 deactivated)
# 17:15:50 INFO    opendrift.models.basemodel:1992: 2024-03-02 21:20:00 - step 273 of 288 - 98 active elements (2 deactivated)
# 17:15:50 INFO    opendrift.models.basemodel:1992: 2024-03-02 21:30:00 - step 274 of 288 - 98 active elements (2 deactivated)
# 17:15:50 INFO    opendrift.models.basemodel:1992: 2024-03-02 21:40:00 - step 275 of 288 - 98 active elements (2 deactivated)
# 17:15:50 INFO    opendrift.models.basemodel:1992: 2024-03-02 21:50:00 - step 276 of 288 - 98 active elements (2 deactivated)
# 17:15:50 INFO    opendrift.models.basemodel:1992: 2024-03-02 22:00:00 - step 277 of 288 - 98 active elements (2 deactivated)
# 17:15:50 INFO    opendrift.models.basemodel:1992: 2024-03-02 22:10:00 - step 278 of 288 - 98 active elements (2 deactivated)
# 17:15:50 INFO    opendrift.models.basemodel:1992: 2024-03-02 22:20:00 - step 279 of 288 - 98 active elements (2 deactivated)
# 17:15:50 INFO    opendrift.models.basemodel:1992: 2024-03-02 22:30:00 - step 280 of 288 - 98 active elements (2 deactivated)
# 17:15:50 INFO    opendrift.models.basemodel:1992: 2024-03-02 22:40:00 - step 281 of 288 - 98 active elements (2 deactivated)
# 17:15:50 INFO    opendrift.models.basemodel:1992: 2024-03-02 22:50:00 - step 282 of 288 - 98 active elements (2 deactivated)
# 17:15:50 INFO    opendrift.models.basemodel:1992: 2024-03-02 23:00:00 - step 283 of 288 - 98 active elements (2 deactivated)
# 17:15:50 INFO    opendrift.models.basemodel:1992: 2024-03-02 23:10:00 - step 284 of 288 - 98 active elements (2 deactivated)
# 17:15:50 INFO    opendrift.models.basemodel:1992: 2024-03-02 23:20:00 - step 285 of 288 - 98 active elements (2 deactivated)
# 17:15:50 INFO    opendrift.models.basemodel:1992: 2024-03-02 23:30:00 - step 286 of 288 - 98 active elements (2 deactivated)
# 17:15:50 INFO    opendrift.models.basemodel:1992: 2024-03-02 23:40:00 - step 287 of 288 - 98 active elements (2 deactivated)
# 17:15:50 INFO    opendrift.models.basemodel:1992: 2024-03-02 23:50:00 - step 288 of 288 - 98 active elements (2 deactivated)
# 17:15:50 INFO    opendrift.export.io_netcdf:112: Wrote 89 steps to file test_output_95_100.nc

# %%
o2.plot(linecolor='z',alpha=0.3)
# Out:
# (<GeoAxes: title={'center': 'OpenDrift - OceanDrift\n2024-03-01 00:00 to 2024-03-03 00:00 UTC (289 steps)'}>,
#  <Figure size 1100x862.518 with 2 Axes>)

# %%
test_out = xr.open_dataset('test_output.nc')

# %%
for i in range(50):
    plt.plot(test_out['lon'][i,:],test_out['lat'][i,:],'.')
    plt.ylim(47.6,47.8)
    plt.xlim(-122.95,-122.75)

# %%
test_out.close()
